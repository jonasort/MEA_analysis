# %%
from neo.io import NeuroExplorerIO
import os
import neo
import elephant
import numpy as np
import pandas as pd
import quantities as pq
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import pyplot
from quantities import ms, s, Hz
from elephant.spike_train_generation import homogeneous_poisson_process, homogeneous_gamma_process
from elephant import neo_tools as nt
from viziphant.rasterplot import rasterplot
from viziphant.spade import plot_patterns
from viziphant.spade import plot_patterns_statistics
import seaborn as sns
import glob

# %%
working_directory = r"D:\Files_Reutlingen_Jenny\main_191023\191023_paper\analysis_spontaneous"

output_directory = r"D:\Files_Reutlingen_Jenny\main_191023\191023_paper\analysis_spontaneous"

# %%
os.chdir(working_directory)

# %%
filelist = glob.glob('*.npy')
filelist
# Out:
# ['191023_whole_recording_burst_connections_dic.npy',
#  'filename_completerecording_full_spikedic.npy',
#  'spiketrain_spade_191023_915_925.npy',
#  'spiketrain_spade_191023_915_925_SPADE_binsize-5_winlen-20_dither-20_spectrum-3d#_statcor-fdr_bh.npy',
#  'spontaneous.h5_0_120_info_dict.npy']

# %%
file_spikedic = glob.glob('*spikedic*')[0]
file_infodic = glob.glob('*info*')[0]

# %%
spikedic_MAD = np.load(file_spikedic, allow_pickle=True).item()
infodic = np.load(file_infodic, allow_pickle=True).item()

# %%
# we gather the general information


tick = infodic['tick']
# the timelength recording must be set to 120 seconds if we observe
timelengthrecording_s = infodic['timelengthrecording_s']
first_recording_timepoint = infodic['first_recording_timepoint']
scale_factor_for_second = infodic['scale_factor_for_second']
scale_factor_for_milisecond = scale_factor_for_second/1000

# %%
# function to subdivide a spiketrain
def subdivide_spiketrain(spiketrain, sub_start = 0, sub_stop = 10, tick=40, scale_factor_for_second=1e-06):
    '''
    Excpects: 
        a spiketrain with tick datapoints
        default ticks are 40
        default scale_factor_for_seconds = 1e-06
        provide the start and stop of the desired sub in seconds
    
    Does:
        converts the desired seconds into data ticks
        checks if the spikes of the given spiketrain is in the desired subs
        substracts the starting time -->
        
    Returns:
        a spiketrain dictionary that again starts from zero
    
    '''
    sub_start_tick = sub_start / (tick*scale_factor_for_second)
    sub_stop_tick = sub_stop / (tick*scale_factor_for_second)
    sub_spiketrain = {}
  
    for key in spiketrain: 
        list_per_key = []
        for i in spiketrain[key]:
            if (i>=sub_start_tick ) & (i<sub_stop_tick):
                list_per_key.append(int(i-sub_start_tick))
        sub_spiketrain[key]=list_per_key

    return sub_spiketrain

# %% [markdown]
# Now that we can define the subpart of the recording we want to observe in SPADE analysis.

# %%
#divide whole spiketrain into subspiketrain
substart = 915
substop = 925 


spade_st = subdivide_spiketrain(spikedic_MAD, sub_start=substart, sub_stop=substop)

# %%
spade_st
# Out:
# {'R12': [],
#  'L10': [],
#  'O10': [4856, 75495, 86954, 88829, 174940, 205299, 248672],
#  'P11': [],
#  'L9': [187057],
#  'N9': [46240],
#  'M8': [],
#  'R8': [],
#  'O6': [],
#  'N7': [210855],
#  'R4': [],
#  'P5': [],
#  'R2': [311,
#   1468,
#   2782,
#   6425,
#   16082,
#   22294,
#   28315,
#   32141,
#   35978,
#   37321,
#   39808,
#   43294,
#   48169,
#   49437,
#   51806,
#   52993,
#   57958,
#   69949,
#   71143,
#   72451,
#   73800,
#   77229,
#   79655,
#   82036,
#   90575,
#   91991,
#   93131,
#   110678,
#   114475,
#   119024,
#   121497,
#   126460,
#   128946,
#   132645,
#   136595,
#   150100,
#   162189,
#   170705,
#   171845,
#   173000,
#   175447,
#   192770,
#   202526,
#   211458,
#   216137,
#   217279,
#   232043,
#   239821,
#   247202,
#   248379],
#  'M5': [122853],
#  'K6': [158259],
#  'I8': [3282, 97285],
#  'L2': [6933, 116978, 139081, 163139],
#  'M1': [],
#  'I4': [151134, 151526, 151777, 152830, 154490],
#  'K3': [],
#  'H1': [],
#  'I6': [141005],
#  'G4': [],
#  'H5': [76731, 78969, 104684, 105624, 106415, 107727, 107954, 116079],
#  'E2': [],
#  'F3': [],
#  'N13': [],
#  'O14': [],
#  'R13': [],
#  'L11': [],
#  'O11': [],
#  'P12': [],
#  'M9': [2671, 86979, 122351, 123358],
#  'N10': [],
#  'L8': [12791,
#   45258,
#   61968,
#   72404,
#   81319,
#   83775,
#   92125,
#   113835,
#   115213,
#   121261,
#   131574,
#   135497,
#   160714,
#   162172,
#   181176,
#   187060,
#   203199,
#   229946,
#   242084],
#  'R9': [],
#  'O7': [],
#  'N8': [5608],
#  'R5': [],
#  'P6': [119179, 141311, 162500, 214816],
#  'K7': [],
#  'L7': [35908,
#   43928,
#   52269,
#   53841,
#   56901,
#   61279,
#   67509,
#   72601,
#   76618,
#   77446,
#   93324,
#   99762,
#   105680,
#   109867,
#   114598,
#   123336,
#   128465,
#   133595,
#   140137,
#   146278,
#   151122,
#   158531,
#   170159,
#   178498,
#   191106,
#   198476,
#   205257,
#   221540,
#   229272,
#   235641,
#   241288,
#   248458],
#  'N4': [118072, 164153],
#  'O3': [75544, 114032, 125471, 192149, 249163],
#  'N1': [89318],
#  'L6': [],
#  'L3': [1442,
#   1490,
#   12085,
#   12137,
#   28872,
#   28918,
#   43987,
#   63244,
#   63295,
#   77817,
#   77868,
#   95390,
#   95452,
#   105953,
#   118775,
#   118819,
#   133001,
#   133053,
#   147432,
#   147487,
#   158975,
#   159018,
#   169077,
#   196137,
#   206627,
#   206683,
#   230312,
#   243805,
#   243855],
#  'M2': [211654],
#  'I5': [],
#  'K4': [],
#  'H6': [22256,
#   89608,
#   100967,
#   101018,
#   101734,
#   103143,
#   103191,
#   104729,
#   106561,
#   110756,
#   113902,
#   201630,
#   204446],
#  'I1': [2792, 176771],
#  'G3': [],
#  'H4': [],
#  'E1': [18690, 170339, 206717, 221861, 235193, 238265],
#  'F2': [],
#  'K13': [114602],
#  'L16': [],
#  'I12': [],
#  'K15': [],
#  'I16': [],
#  'I14': [],
#  'K10': [],
#  'O16': [],
#  'R14': [],
#  'R15': [],
#  'O12': [],
#  'P13': [125353],
#  'M10': [564, 83881, 154701, 170164, 184502, 193959, 228467, 240987],
#  'N11': [],
#  'P9': [],
#  'R10': [],
#  'O8': [],
#  'K8': [162163],
#  'R6': [],
#  'P7': [],
#  'N5': [220865],
#  'M6': [82761, 197349],
#  'P3': [],
#  'O4': [1367,
#   17776,
#   26092,
#   41762,
#   41821,
#   42012,
#   42166,
#   42236,
#   42501,
#   42765,
#   42831,
#   43180,
#   43250,
#   43984,
#   44058,
#   44486,
#   76846,
#   78154,
#   78198,
#   78346,
#   78401,
#   78762,
#   78958,
#   79231,
#   79284,
#   79822,
#   79885,
#   80021,
#   80358,
#   84625,
#   93381,
#   115515,
#   115721,
#   115776,
#   115936,
#   116000,
#   116344,
#   116538,
#   116600,
#   116912,
#   117304,
#   118059,
#   118128,
#   118521,
#   158023,
#   158081,
#   158219,
#   158270,
#   158555,
#   158616,
#   158778,
#   158841,
#   159058,
#   159125,
#   159573,
#   159655,
#   160362,
#   161799,
#   161855,
#   208177,
#   209818,
#   209866,
#   210003,
#   210063,
#   210332,
#   210386,
#   210548,
#   210629,
#   210828,
#   210908,
#   211524,
#   212025,
#   212095,
#   212693,
#   212767,
#   224357],
#  'O1': [],
#  'P1': [],
#  'M3': [5590, 84529, 85196, 86877, 87603, 130670],
#  'N2': [],
#  'K5': [127627,
#   128424,
#   128490,
#   129352,
#   130563,
#   132997,
#   134615,
#   137611,
#   138856,
#   140568,
#   142376,
#   144662,
#   145998,
#   148601,
#   150195,
#   151517,
#   152440,
#   154049,
#   154913,
#   156489,
#   159654,
#   161642,
#   162693],
#  'L4': [2644,
#   9240,
#   19032,
#   26718,
#   35557,
#   35597,
#   44237,
#   53952,
#   62827,
#   70316,
#   77698,
#   90156,
#   106418,
#   114346,
#   122766,
#   123529,
#   132372,
#   142513,
#   150071,
#   159373,
#   166574,
#   173248,
#   178446,
#   185027,
#   193850,
#   201801,
#   201831,
#   207779,
#   222305,
#   239558,
#   246538],
#  'I2': [89837, 161452],
#  'K1': [9470,
#   37133,
#   51952,
#   61856,
#   72728,
#   81955,
#   87266,
#   95914,
#   103628,
#   117294,
#   121939,
#   127200,
#   137203,
#   142699,
#   160718,
#   177437,
#   191352,
#   196361,
#   205271,
#   232665,
#   234975,
#   240489],
#  'H3': [87123],
#  'H7': [89602, 95917, 109931, 213236, 226216],
#  'F1': [240556],
#  'G2': [1381,
#   27254,
#   37010,
#   50770,
#   62246,
#   71791,
#   87140,
#   104221,
#   118989,
#   134023,
#   142757,
#   156600,
#   168776,
#   181246,
#   196817,
#   207140,
#   220710,
#   232536,
#   245000],
#  'E4': [229001],
#  'F5': [117141],
#  'P14': [],
#  'P15': [],
#  'N12': [],
#  'O13': [],
#  'R11': [],
#  'M11': [],
#  'O9': [],
#  'P10': [],
#  'P8': [],
#  'K9': [],
#  'M7': [41601,
#   43349,
#   63341,
#   77055,
#   78803,
#   79953,
#   81410,
#   82753,
#   82812,
#   83638,
#   114916,
#   115819,
#   118053,
#   158953,
#   159994,
#   162145,
#   181243,
#   182830,
#   210980],
#  'R7': [43639,
#   43687,
#   80812,
#   80854,
#   117157,
#   117202,
#   160299,
#   160345,
#   166236,
#   166290,
#   201078,
#   211928,
#   211982],
#  'O5': [41635,
#   41750,
#   41863,
#   42066,
#   42225,
#   42412,
#   42667,
#   42828,
#   43072,
#   43323,
#   43690,
#   43882,
#   44148,
#   44323,
#   44637,
#   44860,
#   45396,
#   46055,
#   47238,
#   77907,
#   78075,
#   78115,
#   78246,
#   78299,
#   78448,
#   78617,
#   78798,
#   79124,
#   79280,
#   79684,
#   79836,
#   80159,
#   80365,
#   80773,
#   81983,
#   115318,
#   115440,
#   115472,
#   115616,
#   115838,
#   116007,
#   116194,
#   116416,
#   116705,
#   116873,
#   117098,
#   117333,
#   117779,
#   117944,
#   118335,
#   118503,
#   119003,
#   119052,
#   119856,
#   121944,
#   157852,
#   158002,
#   158170,
#   158290,
#   158465,
#   158681,
#   158966,
#   159100,
#   159473,
#   159534,
#   159636,
#   160050,
#   160212,
#   160593,
#   160852,
#   161512,
#   161695,
#   161981,
#   162921,
#   164536,
#   209516,
#   209736,
#   209885,
#   210048,
#   210241,
#   210437,
#   210624,
#   210743,
#   210905,
#   211357,
#   211525,
#   211915,
#   212102,
#   212406,
#   212589,
#   213036,
#   213857],
#  'N6': [],
#  'R3': [11148,
#   28390,
#   54285,
#   71140,
#   86840,
#   128942,
#   131519,
#   132639,
#   141537,
#   160978,
#   207666,
#   230831],
#  'P4': [],
#  'O2': [],
#  'P2': [],
#  'M4': [175490],
#  'N3': [65234, 79186, 182126, 184058, 190848, 191517, 192440, 195268, 200668],
#  'L1': [2579,
#   14508,
#   30556,
#   30598,
#   44747,
#   51405,
#   59362,
#   70413,
#   79855,
#   89770,
#   98148,
#   106474,
#   116590,
#   126144,
#   133751,
#   133817,
#   142062,
#   152924,
#   160288,
#   175922,
#   175983,
#   190778,
#   200258,
#   200322,
#   208372,
#   220242,
#   229097,
#   236452,
#   247992],
#  'L5': [67111],
#  'I3': [],
#  'K2': [],
#  'H2': [152959, 154429, 161446],
#  'I7': [97292],
#  'G5': [104084],
#  'G1': [1388,
#   12639,
#   27258,
#   37017,
#   50778,
#   62256,
#   71795,
#   87144,
#   104231,
#   118997,
#   134026,
#   142765,
#   156608,
#   168780,
#   181254,
#   196822,
#   207150,
#   220721,
#   232546,
#   245008],
#  'E3': [],
#  'F4': [87672],
#  'I9': [],
#  'P16': [],
#  'H8': [187993, 203504],
#  'B1': [],
#  'A5': [],
#  'F7': [152642],
#  'C7': [],
#  'B6': [623,
#   24893,
#   51240,
#   59396,
#   74663,
#   118644,
#   161092,
#   168406,
#   192853,
#   193694,
#   215339,
#   236919],
#  'F8': [121010, 153842, 215632],
#  'D8': [],
#  'E9': [4140,
#   9607,
#   13666,
#   19397,
#   22065,
#   99915,
#   108845,
#   111505,
#   116233,
#   123442,
#   148572,
#   152179,
#   157822],
#  'A9': [],
#  'C11': [],
#  'D10': [],
#  'A15': [],
#  'E12': [],
#  'A13': [7588,
#   16741,
#   25121,
#   25168,
#   33908,
#   42567,
#   42612,
#   51613,
#   51653,
#   60162,
#   73653,
#   84498,
#   84547,
#   95534,
#   103543,
#   112795,
#   121799,
#   121848,
#   129146,
#   129193,
#   137812,
#   137847,
#   148591,
#   148646,
#   156203,
#   156247,
#   165624,
#   165661,
#   173927,
#   173982,
#   181015,
#   181052,
#   190945,
#   190995,
#   199254,
#   208447,
#   208490,
#   217160,
#   221903,
#   230919,
#   230974,
#   239334,
#   248586],
#  'B12': [],
#  'F13': [],
#  'K16': [],
#  'E16': [],
#  'I15': [],
#  'I13': [],
#  'H10': [134271],
#  'I11': [],
#  'H14': [],
#  'H12': [],
#  'H16': [143142],
#  'G7': [13734,
#   31285,
#   51187,
#   74500,
#   81443,
#   102456,
#   109603,
#   116860,
#   156629,
#   165091,
#   207601,
#   214607,
#   218382,
#   230235,
#   238098],
#  'G6': [],
#  'D4': [],
#  'C3': [160729, 179856],
#  'A4': [],
#  'F6': [119809],
#  'C6': [],
#  'B5': [],
#  'E8': [4874,
#   16343,
#   27551,
#   38977,
#   65302,
#   82463,
#   105299,
#   115913,
#   122403,
#   129498,
#   147739,
#   159919,
#   182405,
#   197584,
#   224079,
#   237660,
#   249394],
#  'D7': [],
#  'F9': [],
#  'A8': [18087,
#   41392,
#   41438,
#   61033,
#   81103,
#   87344,
#   94201,
#   114898,
#   114947,
#   138788,
#   138832,
#   144199,
#   153881,
#   167570,
#   181144,
#   193759,
#   226118,
#   239888,
#   249316,
#   249373],
#  'C10': [],
#  'D9': [49031],
#  'A12': [],
#  'B11': [205990],
#  'D13': [],
#  'C14': [],
#  'G10': [],
#  'F10': [50818, 65644, 81942, 101876, 172966, 197246],
#  'G13': [],
#  'G15': [],
#  'F14': [],
#  'F16': [],
#  'E15': [36388, 215390],
#  'F12': [2146,
#   6046,
#   8467,
#   10861,
#   15372,
#   19936,
#   23803,
#   28029,
#   32338,
#   36749,
#   40849,
#   41331,
#   45400,
#   46056,
#   49568,
#   52465,
#   53868,
#   57897,
#   61197,
#   61513,
#   62247,
#   66853,
#   71053,
#   74154,
#   74757,
#   79443,
#   83862,
#   84618,
#   88964,
#   92774,
#   94029,
#   95357,
#   97062,
#   102800,
#   107366,
#   108129,
#   112230,
#   114345,
#   116446,
#   119663,
#   123554,
#   123851,
#   124004,
#   128477,
#   133539,
#   137149,
#   141786,
#   142107,
#   146097,
#   149457,
#   152116,
#   153432,
#   157491,
#   159709,
#   160975,
#   164945,
#   168770,
#   171683,
#   176265,
#   177387,
#   180662,
#   184185,
#   188739,
#   193032,
#   196460,
#   200696,
#   205245,
#   207658,
#   208813,
#   213665,
#   217226,
#   218717,
#   221414,
#   225131,
#   226145,
#   229707,
#   234202,
#   237975,
#   242104,
#   246911],
#  'D16': [],
#  'E13': [47491, 153607],
#  'F11': [504,
#   9825,
#   9873,
#   17858,
#   25107,
#   26094,
#   35943,
#   36002,
#   44273,
#   44325,
#   53318,
#   57803,
#   63513,
#   75201,
#   75251,
#   83039,
#   94878,
#   94928,
#   103032,
#   105059,
#   113485,
#   113535,
#   124424,
#   124477,
#   136054,
#   144050,
#   152783,
#   159714,
#   162612,
#   168759,
#   170249,
#   170302,
#   180579,
#   180648,
#   189197,
#   189241,
#   197900,
#   205364,
#   213719,
#   222214,
#   222271,
#   232661,
#   240998,
#   249942,
#   249998],
#  'D14': [64817],
#  'H11': [10766,
#   19682,
#   27829,
#   46399,
#   55032,
#   64089,
#   73436,
#   81862,
#   106515,
#   114373,
#   123318,
#   143142,
#   152639,
#   162334,
#   171689,
#   182248,
#   209034,
#   218211,
#   229062,
#   249603],
#  'I10': [],
#  'H13': [],
#  'H15': [],
#  'G14': [12998, 34480, 86469, 100326, 140363, 154981, 242571],
#  'G16': [],
#  'F15': [],
#  'G12': [],
#  'C2': [],
#  'D3': [],
#  'A3': [],
#  'A2': [],
#  'C5': [],
#  'B4': [],
#  'E7': [],
#  'D6': [],
#  'B8': [],
#  'A7': [4477,
#   12610,
#   12658,
#   19910,
#   19960,
#   27697,
#   35432,
#   35487,
#   42885,
#   42933,
#   50909,
#   59012,
#   67723,
#   67777,
#   76447,
#   84236,
#   84285,
#   91200,
#   91256,
#   98710,
#   106724,
#   106769,
#   113777,
#   121484,
#   129342,
#   136252,
#   143868,
#   150854,
#   150908,
#   158069,
#   158130,
#   165936,
#   173476,
#   173537,
#   181880,
#   189006,
#   195873,
#   195926,
#   203047,
#   211407,
#   211471,
#   218767,
#   218820,
#   227954,
#   227996,
#   235374,
#   242702,
#   242758,
#   249894],
#  'C9': [],
#  'G9': [],
#  'A11': [76288],
#  'B10': [],
#  'D12': [],
#  'E11': [30342, 134831, 136242, 218318, 227766],
#  'C16': [],
#  'B16': [64727],
#  'B14': [],
#  'C13': [],
#  'D15': [],
#  'O15': [92449],
#  'H9': [],
#  'N14': [],
#  'M12': [],
#  'M13': [],
#  'N16': [],
#  'L12': [],
#  'L14': [],
#  'M15': [],
#  'C1': [],
#  'D2': [],
#  'B3': [],
#  'B2': [],
#  'D5': [],
#  'C4': [],
#  'A6': [],
#  'E6': [],
#  'C8': [],
#  'B7': [222041, 222305, 223430, 224251, 225842],
#  'B9': [7946, 61121, 152447, 179259],
#  'G8': [40999, 58225, 68127, 164356, 176027],
#  'E10': [13481,
#   14796,
#   15841,
#   17341,
#   18993,
#   20493,
#   23203,
#   25044,
#   25210,
#   26754,
#   26868,
#   27874,
#   28094,
#   30285,
#   30337,
#   30385,
#   33244,
#   33344,
#   62644,
#   77952,
#   106879,
#   108071,
#   109541,
#   110836,
#   112209,
#   113144,
#   114723,
#   116533,
#   121758,
#   123419,
#   123627,
#   125331,
#   136236,
#   147228,
#   153652,
#   155278,
#   156837,
#   158598,
#   159952,
#   162949,
#   164010,
#   165202,
#   167722,
#   202962,
#   204411,
#   205444,
#   205735,
#   206650,
#   207898,
#   209862,
#   211334,
#   216061,
#   218217,
#   219142,
#   227810,
#   241634],
#  'A10': [],
#  'C12': [],
#  'D11': [],
#  'C15': [],
#  'B15': [],
#  'A14': [],
#  'B13': [],
#  'E14': [],
#  'N15': [],
#  'G11': [6575,
#   13986,
#   20904,
#   28431,
#   35066,
#   42573,
#   49508,
#   56748,
#   64172,
#   71203,
#   79284,
#   83038,
#   86766,
#   94141,
#   103024,
#   111325,
#   119328,
#   127419,
#   136185,
#   144491,
#   152005,
#   159709,
#   167119,
#   175186,
#   183092,
#   190124,
#   197433,
#   204868,
#   212510,
#   220778,
#   228397,
#   235994,
#   243230],
#  'M14': [],
#  'K11': [135531],
#  'L13': [],
#  'M16': [],
#  'K12': [],
#  'K14': [],
#  'L15': [],
#  'E5': [],
#  'D1': [196077]}

# %%
spiketrain_filename = 'spiketrain_spade_191023_'+str(substart)+'_'+str(substop)+'.npy'
np.save(spiketrain_filename, spade_st)

# %% [markdown]
# ### SPADE ANALYSIS
#
# #### This is performed in  KAGGLE or Saturncloud

# %%
spadefile = glob.glob('*spade*SPADE*.npy')

# %%
spadefile
# Out:
# ['spiketrain_spade_191023_915_925_SPADE_binsize-3_winlen-20_dither-20_spectrum-3d#_statcor-fdr_bh.npy',
#  'spiketrain_spade_191023_915_925_SPADE_binsize-5_winlen-20_dither-20_spectrum-3d#_statcor-fdr_bh.npy']

# %%
spadefile = glob.glob('*spade*SPADE*.npy')[1]

# %%
reloadedspikedic = np.load(spiketrain_filename, allow_pickle='TRUE').item()
spade =  np.load(spadefile,allow_pickle='TRUE').item()

# %% [markdown]
# # SPADE RESULTS

# %%
len(spade['patterns'])
# Out:
# 232

# %%
scale_factor_for_second = 1e-06
scale_factor_for_milisecond = 1e-03
tick=40

# %%
spikes = []

for key in reloadedspikedic:
    spikes.append(reloadedspikedic[key])
spikearray = np.sort(np.concatenate(spikes, axis = 0))
spikelist = list(spikearray)

spikearray_sec=spikearray*scale_factor_for_second*tick
recordinglength = round(spikearray_sec[-1]) + 1

# %%
def spikedic_to_neospiketrains(spikedic, recordinglength):
    
    

    spiketrains = [] 
    keylist_spiketrains = []
    for key in reloadedspikedic:
        key_array=np.asarray(reloadedspikedic[key])
        key_array_sec=key_array*1e-06*tick
        if len(key_array_sec)>2:
            st = neo.SpikeTrain(list(key_array_sec), units='sec', t_stop=recordinglength)
            spiketrains.append(st)
            keylist_spiketrains.append(key)
        
    return spiketrains, keylist_spiketrains

# %%
spiketrains, keylist_spiketrains = spikedic_to_neospiketrains(reloadedspikedic, recordinglength)

# %%
keylist_spiketrains
# Out:
# ['O10',
#  'R2',
#  'L2',
#  'I4',
#  'H5',
#  'M9',
#  'L8',
#  'P6',
#  'L7',
#  'O3',
#  'L3',
#  'H6',
#  'E1',
#  'M10',
#  'O4',
#  'M3',
#  'K5',
#  'L4',
#  'K1',
#  'H7',
#  'G2',
#  'M7',
#  'R7',
#  'O5',
#  'R3',
#  'N3',
#  'L1',
#  'H2',
#  'G1',
#  'B6',
#  'F8',
#  'E9',
#  'A13',
#  'G7',
#  'E8',
#  'A8',
#  'F10',
#  'F12',
#  'F11',
#  'H11',
#  'G14',
#  'A7',
#  'E11',
#  'B7',
#  'B9',
#  'G8',
#  'E10',
#  'G11']

# %%
spiketrains
# Out:
# [SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain,
#  SpikeTrain]

# %%
plot_patterns_statistics(spade['patterns'])
# Out:
# (<Figure size 720x720 with 4 Axes>,
#  array([<AxesSubplot:title={'center':'Patterns statistics'}, xlabel='Neuronal participation in patterns', ylabel='Count'>,
#         <AxesSubplot:xlabel='Pattern occurrences', ylabel='Count'>,
#         <AxesSubplot:xlabel='Pattern size', ylabel='Count'>,
#         <AxesSubplot:xlabel='Lags (ms)', ylabel='Count'>], dtype=object))

# %%
patterns = spade['patterns']

# %%
plot_patterns(spiketrains=spiketrains, patterns=patterns[3:6])
# Out:
# <AxesSubplot:xlabel='Time (s)', ylabel='Neuron'>

# %%
type(spikearray_sec)
# Out:
# numpy.ndarray

# %%
def make_pattern_dic(patterns):
    
    patterndic = {}
    for i in range(0, len(patterns)):
        key='P'+str(i)
        patterndic[key]=[(patterns[i]['neurons']),(patterns[i]['lags'])]
        
    
    return patterndic

# %%
patterndic = make_pattern_dic(patterns)

# %%
patterns
# Out:
# [{'itemset': (636,
#    627,
#    631,
#    624,
#    919,
#    622,
#    628,
#    630,
#    911,
#    903,
#    914,
#    904,
#    909,
#    901,
#    907,
#    905,
#    900),
#   'windows_ids': (623, 1676),
#   'neurons': [45,
#    45,
#    31,
#    45,
#    31,
#    45,
#    45,
#    31,
#    45,
#    31,
#    45,
#    31,
#    45,
#    31,
#    45,
#    31,
#    45],
#   'lags': array([ 5., 10., 15., 20., 20., 25., 35., 35., 40., 45., 50., 55., 55.,
#          70., 80., 95.]) * ms,
#   'times': array([3115., 8380.]) * ms,
#   'signature': (17, 2, 19),
#   'pvalue': 0.012},
#  {'itemset': (635,
#    624,
#    630,
#    628,
#    918,
#    622,
#    919,
#    623,
#    903,
#    915,
#    914,
#    902,
#    904,
#    909,
#    907,
#    905,
#    900),
#   'windows_ids': (623, 1262),
#   'neurons': [45,
#    45,
#    31,
#    31,
#    45,
#    31,
#    45,
#    45,
#    45,
#    31,
#    45,
#    31,
#    45,
#    45,
#    31,
#    45,
#    45],
#   'lags': array([10., 10., 15., 15., 20., 20., 25., 35., 40., 45., 50., 70., 75.,
#          75., 90., 95.]) * ms,
#   'times': array([3115., 6310.]) * ms,
#   'signature': (17, 2, 19),
#   'pvalue': 0.012},
#  {'itemset': (864, 633, 624, 623, 916, 902, 912, 904, 909, 907, 900),
#   'windows_ids': (342, 922, 1683),
#   'neurons': [45, 45, 31, 43, 31, 45, 45, 45, 45, 31, 45],
#   'lags': array([10., 15., 20., 20., 20., 35., 45., 60., 65., 80.]) * ms,
#   'times': array([1710., 4610., 8415.]) * ms,
#   'signature': (11, 3, 16),
#   'pvalue': 0.016},
#  {'itemset': (638, 632, 626, 620, 917, 908, 903, 902, 912, 907, 905, 900),
#   'windows_ids': (334, 926, 1264),
#   'neurons': [31, 45, 45, 45, 45, 31, 45, 45, 31, 45, 45, 31],
#   'lags': array([ 0., 10., 15., 25., 30., 35., 40., 60., 60., 85., 90.]) * ms,
#   'times': array([1670., 4630., 6320.]) * ms,
#   'signature': (12, 3, 18),
#   'pvalue': 0.007},
#  {'itemset': (636, 631, 624, 630, 622, 911, 903, 914, 909, 901, 905, 900),
#   'windows_ids': (623, 1266, 1676),
#   'neurons': [45, 45, 31, 45, 31, 45, 45, 31, 31, 45, 45, 31],
#   'lags': array([ 5., 10., 15., 20., 25., 45., 50., 55., 55., 70., 80.]) * ms,
#   'times': array([3115., 6330., 8380.]) * ms,
#   'signature': (12, 3, 16),
#   'pvalue': 0.002},
#  {'itemset': (636, 624, 630, 628, 622, 911, 914, 904, 909, 901, 907, 900),
#   'windows_ids': (623, 922, 1676),
#   'neurons': [45, 45, 31, 31, 45, 45, 31, 45, 31, 45, 45, 31],
#   'lags': array([ 5., 10., 20., 20., 35., 40., 45., 50., 55., 70., 80.]) * ms,
#   'times': array([3115., 4610., 8380.]) * ms,
#   'signature': (12, 3, 16),
#   'pvalue': 0.002},
#  {'itemset': (634, 630, 623, 626, 918, 622, 914, 913, 902, 910, 904, 900),
#   'windows_ids': (624, 628, 1262),
#   'neurons': [45, 31, 45, 31, 45, 31, 31, 45, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 50., 50., 65., 70., 70., 90.]) * ms,
#   'times': array([3120., 3140., 6310.]) * ms,
#   'signature': (12, 3, 18),
#   'pvalue': 0.007},
#  {'itemset': (633, 627, 624, 621, 916, 906, 908, 911, 904, 901, 900),
#   'windows_ids': (333, 626, 1679),
#   'neurons': [45, 31, 45, 31, 45, 45, 31, 45, 45, 31, 45],
#   'lags': array([ 5.,  5., 20., 20., 30., 35., 40., 55., 65., 80.]) * ms,
#   'times': array([1665., 3130., 8395.]) * ms,
#   'signature': (11, 3, 16),
#   'pvalue': 0.016},
#  {'itemset': (633, 625, 624, 628, 916, 906, 911, 902, 904, 901, 900),
#   'windows_ids': (626, 922, 1679),
#   'neurons': [45, 45, 45, 31, 45, 31, 45, 31, 45, 31, 45],
#   'lags': array([ 5., 10., 20., 20., 25., 30., 40., 55., 65., 80.]) * ms,
#   'times': array([3130., 4610., 8395.]) * ms,
#   'signature': (11, 3, 16),
#   'pvalue': 0.016},
#  {'itemset': (629, 635, 630, 626, 918, 621, 906, 908, 903, 913, 910, 900),
#   'windows_ids': (336, 624, 1677),
#   'neurons': [45, 31, 45, 31, 45, 45, 31, 31, 45, 45, 31, 45],
#   'lags': array([ 5., 15., 30., 30., 40., 45., 50., 50., 65., 75., 90.]) * ms,
#   'times': array([1680., 3120., 8385.]) * ms,
#   'signature': (12, 3, 18),
#   'pvalue': 0.007},
#  {'itemset': (635, 624, 623, 622, 918, 919, 903, 915, 914, 902, 904, 909, 900),
#   'windows_ids': (623, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 15., 20., 20., 45., 70., 75., 75., 90., 95.]) * ms,
#   'times': array([3115., 6310., 8405.]) * ms,
#   'signature': (13, 3, 19),
#   'pvalue': 0.001},
#  {'itemset': (635, 630, 628, 623, 918, 919, 903, 915, 902, 904, 907, 900),
#   'windows_ids': (623, 1262, 1677),
#   'neurons': [45, 45, 31, 45, 45, 45, 31, 31, 31, 45, 45, 45],
#   'lags': array([10., 15., 15., 20., 35., 40., 50., 75., 75., 90., 95.]) * ms,
#   'times': array([3115., 6310., 8385.]) * ms,
#   'signature': (12, 3, 19),
#   'pvalue': 0.006},
#  {'itemset': (624, 630, 628, 623, 622, 914, 902, 904, 909, 907, 900),
#   'windows_ids': (623, 922, 1262),
#   'neurons': [45, 31, 45, 31, 31, 45, 45, 31, 45, 31, 45],
#   'lags': array([10., 10., 15., 20., 20., 35., 40., 45., 50., 70.]) * ms,
#   'times': array([3115., 4610., 6310.]) * ms,
#   'signature': (11, 3, 14),
#   'pvalue': 0.006},
#  {'itemset': (624, 630, 628, 919, 903, 622, 914, 904, 909, 907, 905, 900),
#   'windows_ids': (623, 1262, 1676),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 15., 20., 20., 25., 35., 40., 45., 50., 70., 95.]) * ms,
#   'times': array([3115., 6310., 8380.]) * ms,
#   'signature': (12, 3, 19),
#   'pvalue': 0.006},
#  {'itemset': (628, 623, 919, 622, 918, 914, 902, 907, 904, 909, 905, 900),
#   'windows_ids': (623, 924, 1262),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 25., 35., 40., 45., 70., 90., 95.]) * ms,
#   'times': array([3115., 4620., 6310.]) * ms,
#   'signature': (12, 3, 19),
#   'pvalue': 0.006},
#  {'itemset': (638, 626, 620, 903, 917, 905, 902, 912, 907),
#   'windows_ids': (334, 926, 1264, 1678),
#   'neurons': [31, 45, 45, 45, 31, 45, 45, 45, 31],
#   'lags': array([10., 15., 25., 30., 35., 60., 85., 90.]) * ms,
#   'times': array([1670., 4630., 6320., 8390.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (636, 624, 630, 622, 911, 914, 901, 900, 909),
#   'windows_ids': (623, 922, 1266, 1676),
#   'neurons': [45, 45, 31, 31, 45, 31, 45, 45, 31],
#   'lags': array([ 5., 10., 20., 45., 50., 55., 70., 80.]) * ms,
#   'times': array([3115., 4610., 6330., 8380.]) * ms,
#   'signature': (9, 4, 16),
#   'pvalue': 0.009},
#  {'itemset': (636, 624, 630, 622, 903, 914, 901, 900, 905),
#   'windows_ids': (623, 928, 1266, 1676),
#   'neurons': [45, 45, 31, 45, 31, 45, 31, 45, 31],
#   'lags': array([ 5., 10., 15., 20., 25., 50., 70., 80.]) * ms,
#   'times': array([3115., 4640., 6330., 8380.]) * ms,
#   'signature': (9, 4, 16),
#   'pvalue': 0.009},
#  {'itemset': (636, 624, 630, 918, 903, 915, 901, 905, 900),
#   'windows_ids': (336, 623, 928, 1266),
#   'neurons': [45, 45, 45, 31, 45, 31, 45, 31, 45],
#   'lags': array([ 5., 15., 20., 25., 50., 75., 80., 90.]) * ms,
#   'times': array([1680., 3115., 4640., 6330.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (634, 623, 626, 622, 918, 914, 902, 910, 904, 900),
#   'windows_ids': (624, 628, 924, 1262),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 50., 70., 70., 90.]) * ms,
#   'times': array([3120., 3140., 4620., 6310.]) * ms,
#   'signature': (10, 4, 18),
#   'pvalue': 0.001},
#  {'itemset': (627, 632, 623, 919, 903, 915, 910, 900, 905),
#   'windows_ids': (339, 627, 923, 1680),
#   'neurons': [45, 31, 45, 45, 31, 45, 31, 45, 45],
#   'lags': array([15., 15., 25., 35., 50., 60., 75., 95.]) * ms,
#   'times': array([1695., 3135., 4615., 8400.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (627, 629, 623, 621, 906, 908, 903, 913, 900),
#   'windows_ids': (333, 624, 923, 1677),
#   'neurons': [45, 31, 31, 45, 45, 31, 45, 31, 45],
#   'lags': array([ 5., 15., 15., 30., 35., 40., 45., 65.]) * ms,
#   'times': array([1665., 3120., 4615., 8385.]) * ms,
#   'signature': (9, 4, 13),
#   'pvalue': 0.005},
#  {'itemset': (627, 624, 623, 919, 903, 915, 901, 905, 900),
#   'windows_ids': (623, 627, 923, 1680),
#   'neurons': [45, 45, 31, 45, 31, 45, 31, 45, 45],
#   'lags': array([ 5., 15., 15., 20., 25., 35., 75., 95.]) * ms,
#   'times': array([3115., 3135., 4615., 8400.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (627, 623, 626, 919, 903, 915, 910, 907, 900),
#   'windows_ids': (339, 627, 1677, 1680),
#   'neurons': [45, 31, 45, 31, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 30., 35., 35., 50., 75., 95.]) * ms,
#   'times': array([1695., 3135., 8385., 8400.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (632, 628, 621, 620, 916, 908, 911, 912, 900),
#   'windows_ids': (626, 630, 1264, 1684),
#   'neurons': [31, 45, 31, 31, 45, 45, 31, 45, 45],
#   'lags': array([ 0.,  5., 40., 40., 55., 60., 60., 80.]) * ms,
#   'times': array([3130., 3150., 6320., 8420.]) * ms,
#   'signature': (9, 4, 16),
#   'pvalue': 0.009},
#  {'itemset': (632, 623, 626, 919, 903, 915, 910, 907, 905, 900),
#   'windows_ids': (334, 339, 627, 1680),
#   'neurons': [45, 31, 45, 45, 31, 45, 45, 31, 45, 45],
#   'lags': array([15., 15., 25., 30., 35., 50., 60., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 8400.]) * ms,
#   'signature': (10, 4, 19),
#   'pvalue': 0.002},
#  {'itemset': (629, 635, 621, 906, 913, 900, 908, 903, 910),
#   'windows_ids': (336, 624, 923, 1677),
#   'neurons': [45, 31, 45, 45, 45, 31, 45, 45, 31],
#   'lags': array([ 5., 15., 30., 40., 45., 50., 65., 75.]) * ms,
#   'times': array([1680., 3120., 4615., 8385.]) * ms,
#   'signature': (9, 4, 15),
#   'pvalue': 0.008},
#  {'itemset': (631, 628, 919, 622, 914, 907, 905, 900, 909),
#   'windows_ids': (344, 623, 924, 1676),
#   'neurons': [45, 31, 45, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 25., 35., 40., 45., 55., 70., 95.]) * ms,
#   'times': array([1720., 3115., 4620., 8380.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (631, 623, 622, 918, 914, 902, 904, 909, 900),
#   'windows_ids': (623, 628, 924, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 45., 55., 70., 90.]) * ms,
#   'times': array([3115., 3140., 4620., 8405.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (635, 623, 919, 918, 903, 915, 902, 904, 900),
#   'windows_ids': (623, 1262, 1677, 1681),
#   'neurons': [45, 45, 31, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 15., 20., 75., 75., 90., 95.]) * ms,
#   'times': array([3115., 6310., 8385., 8405.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (635, 623, 919, 914, 902, 905, 904, 909, 900),
#   'windows_ids': (623, 929, 1262, 1267),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 31, 45],
#   'lags': array([10., 15., 20., 25., 45., 70., 75., 95.]) * ms,
#   'times': array([3115., 4645., 6310., 6335.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (635, 623, 622, 918, 903, 914, 902, 904, 900),
#   'windows_ids': (623, 624, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 31, 45],
#   'lags': array([10., 10., 15., 15., 20., 70., 75., 90.]) * ms,
#   'times': array([3115., 3120., 6310., 8405.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (635, 623, 914, 902, 904, 909, 907, 900, 905),
#   'windows_ids': (337, 623, 929, 1262),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 45, 31],
#   'lags': array([10., 15., 20., 25., 35., 45., 70., 75.]) * ms,
#   'times': array([1685., 3115., 4645., 6310.]) * ms,
#   'signature': (9, 4, 15),
#   'pvalue': 0.008},
#  {'itemset': (624, 630, 628, 622, 900, 914, 904, 909, 907),
#   'windows_ids': (623, 922, 1262, 1676),
#   'neurons': [45, 31, 31, 45, 45, 31, 45, 31, 45],
#   'lags': array([10., 20., 20., 35., 40., 45., 50., 70.]) * ms,
#   'times': array([3115., 4610., 6310., 8380.]) * ms,
#   'signature': (9, 4, 14),
#   'pvalue': 0.007},
#  {'itemset': (624, 630, 622, 918, 915, 903, 914, 905, 900),
#   'windows_ids': (623, 928, 1262, 1266),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 50., 70., 75., 90.]) * ms,
#   'times': array([3115., 4640., 6310., 6330.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (624, 623, 622, 902, 904, 907, 909, 900),
#   'windows_ids': (623, 922, 1262, 1683),
#   'neurons': [45, 31, 45, 31, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 20., 35., 45.]) * ms,
#   'times': array([3115., 4610., 6310., 8415.]) * ms,
#   'signature': (8, 4, 9),
#   'pvalue': 0.016},
#  {'itemset': (630, 623, 626, 918, 913, 902, 910, 904, 900),
#   'windows_ids': (624, 628, 1262, 1677),
#   'neurons': [45, 45, 31, 45, 31, 31, 45, 45, 45],
#   'lags': array([10., 15., 20., 30., 50., 50., 65., 90.]) * ms,
#   'times': array([3120., 3140., 6310., 8385.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (628, 623, 622, 914, 902, 904, 909, 907, 900),
#   'windows_ids': (623, 922, 924, 1262),
#   'neurons': [45, 31, 45, 31, 45, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 35., 40., 45., 70.]) * ms,
#   'times': array([3115., 4610., 4620., 6310.]) * ms,
#   'signature': (9, 4, 14),
#   'pvalue': 0.007},
#  {'itemset': (628, 623, 914, 902, 905, 904, 909, 907, 900),
#   'windows_ids': (337, 623, 924, 1262),
#   'neurons': [45, 45, 31, 45, 45, 45, 31, 45, 45],
#   'lags': array([10., 15., 20., 25., 35., 40., 45., 70.]) * ms,
#   'times': array([1685., 3115., 4620., 6310.]) * ms,
#   'signature': (9, 4, 14),
#   'pvalue': 0.007},
#  {'itemset': (628, 626, 622, 917, 620, 903, 902, 912, 907, 905),
#   'windows_ids': (334, 625, 1264, 1678),
#   'neurons': [31, 31, 45, 45, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 25., 30., 35., 40., 60., 85.]) * ms,
#   'times': array([1670., 3125., 6320., 8390.]) * ms,
#   'signature': (10, 4, 17),
#   'pvalue': 0.002},
#  {'itemset': (628, 626, 622, 620, 900, 902, 912, 907, 905),
#   'windows_ids': (334, 625, 924, 1264),
#   'neurons': [31, 45, 31, 45, 45, 31, 45, 31, 45],
#   'lags': array([ 0., 10., 10., 25., 30., 35., 40., 60.]) * ms,
#   'times': array([1670., 3125., 4620., 6320.]) * ms,
#   'signature': (9, 4, 12),
#   'pvalue': 0.003},
#  {'itemset': (628, 626, 622, 903, 902, 900, 905, 907),
#   'windows_ids': (334, 625, 1262, 1264),
#   'neurons': [45, 31, 45, 45, 45, 31, 45, 31],
#   'lags': array([10., 10., 15., 25., 30., 35., 40.]) * ms,
#   'times': array([1670., 3125., 6310., 6320.]) * ms,
#   'signature': (8, 4, 8),
#   'pvalue': 0.015},
#  {'itemset': (628, 919, 622, 914, 902, 900, 907, 909, 905),
#   'windows_ids': (344, 623, 924, 1262),
#   'neurons': [45, 31, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 25., 35., 40., 45., 70., 95.]) * ms,
#   'times': array([1720., 3115., 4620., 6310.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (628, 919, 622, 914, 904, 900, 907, 909, 905),
#   'windows_ids': (623, 924, 1262, 1676),
#   'neurons': [45, 31, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 20., 25., 35., 40., 45., 70., 95.]) * ms,
#   'times': array([3115., 4620., 6310., 8380.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 626, 919, 622, 914, 900, 902, 904, 909),
#   'windows_ids': (349, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 45., 70., 95.]) * ms,
#   'times': array([1745., 4620., 6310., 8405.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 626, 919, 903, 902, 910, 900, 915, 907),
#   'windows_ids': (334, 339, 1262, 1677),
#   'neurons': [45, 45, 31, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 15., 30., 35., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 6310., 8385.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 626, 919, 914, 902, 904, 905, 900, 909),
#   'windows_ids': (349, 924, 929, 1262),
#   'neurons': [45, 45, 31, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 30., 45., 70., 95.]) * ms,
#   'times': array([1745., 4620., 4645., 6310.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 626, 622, 918, 909, 914, 902, 904, 900),
#   'windows_ids': (628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 45., 70., 90.]) * ms,
#   'times': array([3140., 4620., 6310., 8405.]) * ms,
#   'signature': (9, 4, 18),
#   'pvalue': 0.016},
#  {'itemset': (623, 919, 622, 918, 914, 902, 904, 909, 900),
#   'windows_ids': (623, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 45., 70., 90., 95.]) * ms,
#   'times': array([3115., 4620., 6310., 8405.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 919, 622, 914, 905, 902, 904, 909, 900),
#   'windows_ids': (349, 623, 924, 1262),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 25., 45., 70., 95.]) * ms,
#   'times': array([1745., 3115., 4620., 6310.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 919, 914, 902, 904, 907, 900, 909, 905),
#   'windows_ids': (623, 924, 929, 1262),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 35., 45., 70., 95.]) * ms,
#   'times': array([3115., 4620., 4645., 6310.]) * ms,
#   'signature': (9, 4, 19),
#   'pvalue': 0.008},
#  {'itemset': (626, 917, 620, 908, 903, 912, 905, 900, 907),
#   'windows_ids': (334, 346, 926, 1264),
#   'neurons': [31, 45, 45, 45, 31, 45, 45, 45, 45],
#   'lags': array([ 0., 15., 25., 30., 35., 40., 60., 85.]) * ms,
#   'times': array([1670., 1730., 4630., 6320.]) * ms,
#   'signature': (9, 4, 17),
#   'pvalue': 0.014},
#  {'itemset': (626, 917, 620, 903, 902, 900, 905, 912, 907),
#   'windows_ids': (334, 625, 926, 1264),
#   'neurons': [31, 45, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([ 0., 10., 15., 25., 30., 35., 60., 85.]) * ms,
#   'times': array([1670., 3125., 4630., 6320.]) * ms,
#   'signature': (9, 4, 17),
#   'pvalue': 0.014},
#  {'itemset': (627, 624, 622, 900, 903, 901, 905),
#   'windows_ids': (623, 923, 928, 1676, 1680),
#   'neurons': [45, 45, 31, 45, 31, 45, 31],
#   'lags': array([ 5., 10., 15., 20., 25., 35.]) * ms,
#   'times': array([3115., 4615., 4640., 8380., 8400.]) * ms,
#   'signature': (7, 5, 7),
#   'pvalue': 0.005},
#  {'itemset': (627, 623, 621, 906, 908, 903, 900),
#   'windows_ids': (333, 624, 923, 1269, 1677),
#   'neurons': [45, 31, 31, 45, 45, 31, 45],
#   'lags': array([ 5., 15., 15., 30., 35., 40.]) * ms,
#   'times': array([1665., 3120., 4615., 6345., 8385.]) * ms,
#   'signature': (7, 5, 8),
#   'pvalue': 0.013},
#  {'itemset': (632, 623, 919, 903, 900, 915, 910, 905),
#   'windows_ids': (334, 339, 627, 923, 1680),
#   'neurons': [45, 31, 45, 45, 45, 31, 45, 45],
#   'lags': array([15., 15., 25., 50., 60., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4615., 8400.]) * ms,
#   'signature': (8, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (635, 623, 919, 914, 902, 904, 909, 900),
#   'windows_ids': (623, 929, 1262, 1267, 1681),
#   'neurons': [45, 45, 31, 45, 45, 45, 31, 45],
#   'lags': array([10., 15., 20., 45., 70., 75., 95.]) * ms,
#   'times': array([3115., 4645., 6310., 6335., 8405.]) * ms,
#   'signature': (8, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (635, 623, 914, 902, 904, 909, 905, 900),
#   'windows_ids': (337, 623, 929, 1262, 1267),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 31],
#   'lags': array([10., 15., 20., 25., 45., 70., 75.]) * ms,
#   'times': array([1685., 3115., 4645., 6310., 6335.]) * ms,
#   'signature': (8, 5, 15),
#   'pvalue': 0.0},
#  {'itemset': (624, 626, 620, 901, 900, 903, 905),
#   'windows_ids': (336, 627, 1264, 1266, 1680),
#   'neurons': [31, 45, 45, 45, 31, 45, 31],
#   'lags': array([ 0.,  5., 15., 20., 25., 30.]) * ms,
#   'times': array([1680., 3135., 6320., 6330., 8400.]) * ms,
#   'signature': (7, 5, 6),
#   'pvalue': 0.004},
#  {'itemset': (628, 623, 914, 902, 904, 909, 907, 900),
#   'windows_ids': (337, 623, 922, 924, 1262),
#   'neurons': [45, 45, 31, 45, 45, 31, 45, 45],
#   'lags': array([10., 15., 20., 35., 40., 45., 70.]) * ms,
#   'times': array([1685., 3115., 4610., 4620., 6310.]) * ms,
#   'signature': (8, 5, 14),
#   'pvalue': 0.001},
#  {'itemset': (628, 626, 622, 620, 902, 912, 907, 905),
#   'windows_ids': (334, 625, 924, 1264, 1678),
#   'neurons': [31, 31, 45, 45, 31, 45, 31, 45],
#   'lags': array([10., 10., 25., 30., 35., 40., 60.]) * ms,
#   'times': array([1670., 3125., 4620., 6320., 8390.]) * ms,
#   'signature': (8, 5, 12),
#   'pvalue': 0.002},
#  {'itemset': (628, 626, 622, 903, 900, 905, 907),
#   'windows_ids': (334, 625, 1262, 1264, 1676),
#   'neurons': [45, 31, 45, 45, 31, 45, 31],
#   'lags': array([10., 15., 25., 30., 35., 40.]) * ms,
#   'times': array([1670., 3125., 6310., 6320., 8380.]) * ms,
#   'signature': (7, 5, 8),
#   'pvalue': 0.013},
#  {'itemset': (628, 626, 622, 902, 907, 900, 905),
#   'windows_ids': (334, 625, 924, 1262, 1264),
#   'neurons': [45, 31, 45, 45, 31, 45, 31],
#   'lags': array([10., 10., 25., 30., 35., 40.]) * ms,
#   'times': array([1670., 3125., 4620., 6310., 6320.]) * ms,
#   'signature': (7, 5, 8),
#   'pvalue': 0.013},
#  {'itemset': (628, 919, 622, 914, 900, 907, 909, 905),
#   'windows_ids': (344, 623, 924, 1262, 1676),
#   'neurons': [45, 31, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 25., 35., 40., 45., 70., 95.]) * ms,
#   'times': array([1720., 3115., 4620., 6310., 8380.]) * ms,
#   'signature': (8, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (628, 622, 903, 902, 905, 900, 907),
#   'windows_ids': (334, 623, 625, 1262, 1264),
#   'neurons': [45, 31, 45, 45, 45, 45, 31],
#   'lags': array([10., 10., 15., 25., 35., 40.]) * ms,
#   'times': array([1670., 3115., 3125., 6310., 6320.]) * ms,
#   'signature': (7, 5, 8),
#   'pvalue': 0.013},
#  {'itemset': (623, 626, 919, 903, 910, 905, 900, 915, 907),
#   'windows_ids': (334, 339, 627, 1262, 1680),
#   'neurons': [45, 31, 45, 45, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 25., 30., 35., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 6310., 8400.]) * ms,
#   'signature': (9, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 626, 919, 914, 902, 904, 900, 909),
#   'windows_ids': (349, 924, 929, 1262, 1681),
#   'neurons': [45, 45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 20., 30., 45., 70., 95.]) * ms,
#   'times': array([1745., 4620., 4645., 6310., 8405.]) * ms,
#   'signature': (8, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 626, 622, 918, 914, 902, 904, 900),
#   'windows_ids': (624, 628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 70., 90.]) * ms,
#   'times': array([3120., 3140., 4620., 6310., 8405.]) * ms,
#   'signature': (8, 5, 18),
#   'pvalue': 0.003},
#  {'itemset': (623, 626, 622, 914, 909, 900, 902, 904),
#   'windows_ids': (349, 628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 30., 45., 70.]) * ms,
#   'times': array([1745., 3140., 4620., 6310., 8405.]) * ms,
#   'signature': (8, 5, 14),
#   'pvalue': 0.001},
#  {'itemset': (623, 919, 622, 914, 902, 904, 909, 900),
#   'windows_ids': (349, 623, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 45., 70., 95.]) * ms,
#   'times': array([1745., 3115., 4620., 6310., 8405.]) * ms,
#   'signature': (8, 5, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 622, 918, 914, 904, 909, 902, 900),
#   'windows_ids': (623, 628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 45., 70., 90.]) * ms,
#   'times': array([3115., 3140., 4620., 6310., 8405.]) * ms,
#   'signature': (8, 5, 18),
#   'pvalue': 0.003},
#  {'itemset': (623, 914, 902, 904, 909, 907, 905, 900),
#   'windows_ids': (337, 623, 924, 929, 1262),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 35., 45., 70.]) * ms,
#   'times': array([1685., 3115., 4620., 4645., 6310.]) * ms,
#   'signature': (8, 5, 14),
#   'pvalue': 0.001},
#  {'itemset': (626, 917, 620, 903, 902, 905, 912, 907),
#   'windows_ids': (334, 625, 926, 1264, 1678),
#   'neurons': [31, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 25., 30., 35., 60., 85.]) * ms,
#   'times': array([1670., 3125., 4630., 6320., 8390.]) * ms,
#   'signature': (8, 5, 17),
#   'pvalue': 0.0},
#  {'itemset': (626, 917, 620, 903, 912, 900, 905, 907),
#   'windows_ids': (334, 346, 625, 926, 1264),
#   'neurons': [31, 45, 45, 45, 31, 45, 45, 45],
#   'lags': array([ 0., 15., 25., 30., 35., 60., 85.]) * ms,
#   'times': array([1670., 1730., 3125., 4630., 6320.]) * ms,
#   'signature': (8, 5, 17),
#   'pvalue': 0.0},
#  {'itemset': (632, 919, 903, 915, 900, 910, 905),
#   'windows_ids': (334, 339, 627, 923, 933, 1680),
#   'neurons': [45, 45, 45, 45, 31, 45, 45],
#   'lags': array([15., 25., 50., 60., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4615., 4665., 8400.]) * ms,
#   'signature': (7, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (629, 916, 620, 902, 912, 907, 900),
#   'windows_ids': (337, 342, 625, 630, 926, 1683),
#   'neurons': [31, 45, 45, 45, 31, 45, 45],
#   'lags': array([ 0., 10., 35., 45., 60., 80.]) * ms,
#   'times': array([1685., 1710., 3125., 3150., 4630., 8415.]) * ms,
#   'signature': (7, 6, 16),
#   'pvalue': 0.002},
#  {'itemset': (635, 623, 914, 902, 904, 909, 900),
#   'windows_ids': (337, 623, 929, 1262, 1267, 1681),
#   'neurons': [45, 45, 31, 45, 45, 45, 31],
#   'lags': array([10., 15., 20., 45., 70., 75.]) * ms,
#   'times': array([1685., 3115., 4645., 6310., 6335., 8405.]) * ms,
#   'signature': (7, 6, 15),
#   'pvalue': 0.001},
#  {'itemset': (625, 623, 906, 904, 900, 902),
#   'windows_ids': (628, 922, 1265, 1677, 1679, 1681),
#   'neurons': [45, 45, 31, 45, 31, 45],
#   'lags': array([10., 15., 20., 25., 30.]) * ms,
#   'times': array([3140., 4610., 6325., 8385., 8395., 8405.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (624, 626, 620, 901, 903, 905),
#   'windows_ids': (336, 627, 1264, 1266, 1678, 1680),
#   'neurons': [31, 45, 45, 31, 45, 31],
#   'lags': array([ 5., 15., 20., 25., 30.]) * ms,
#   'times': array([1680., 3135., 6320., 6330., 8390., 8400.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (624, 626, 620, 905, 900, 903),
#   'windows_ids': (336, 627, 926, 1264, 1266, 1680),
#   'neurons': [31, 45, 45, 31, 45, 31],
#   'lags': array([ 0., 15., 20., 25., 30.]) * ms,
#   'times': array([1680., 3135., 4630., 6320., 6330., 8400.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (624, 626, 903, 901, 900, 905),
#   'windows_ids': (336, 627, 1264, 1266, 1676, 1680),
#   'neurons': [45, 45, 45, 31, 45, 31],
#   'lags': array([ 5., 15., 20., 25., 30.]) * ms,
#   'times': array([1680., 3135., 6320., 6330., 8380., 8400.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (624, 903, 915, 910, 901, 900, 905),
#   'windows_ids': (336, 627, 923, 928, 1266, 1680),
#   'neurons': [45, 45, 45, 31, 45, 45, 45],
#   'lags': array([ 5., 15., 20., 25., 50., 75.]) * ms,
#   'times': array([1680., 3135., 4615., 4640., 6330., 8400.]) * ms,
#   'signature': (7, 6, 15),
#   'pvalue': 0.001},
#  {'itemset': (623, 626, 919, 903, 910, 900, 915, 907),
#   'windows_ids': (334, 339, 627, 1262, 1677, 1680),
#   'neurons': [45, 31, 45, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 30., 35., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 6310., 8385., 8400.]) * ms,
#   'signature': (8, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 626, 919, 910, 905, 900, 907),
#   'windows_ids': (334, 339, 627, 924, 1262, 1680),
#   'neurons': [45, 31, 45, 31, 45, 45, 45],
#   'lags': array([15., 25., 30., 35., 50., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4620., 6310., 8400.]) * ms,
#   'signature': (7, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 626, 621, 904, 902, 900),
#   'windows_ids': (624, 924, 929, 1677, 1679, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31],
#   'lags': array([ 5., 10., 15., 20., 30.]) * ms,
#   'times': array([3120., 4620., 4645., 8385., 8395., 8405.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (623, 626, 622, 914, 900, 902, 904),
#   'windows_ids': (349, 624, 628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 31, 45],
#   'lags': array([10., 10., 15., 20., 30., 70.]) * ms,
#   'times': array([1745., 3120., 3140., 4620., 6310., 8405.]) * ms,
#   'signature': (7, 6, 14),
#   'pvalue': 0.003},
#  {'itemset': (623, 626, 914, 902, 904, 909, 900),
#   'windows_ids': (349, 628, 924, 929, 1262, 1681),
#   'neurons': [45, 45, 31, 45, 31, 45, 45],
#   'lags': array([10., 15., 20., 30., 45., 70.]) * ms,
#   'times': array([1745., 3140., 4620., 4645., 6310., 8405.]) * ms,
#   'signature': (7, 6, 14),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 903, 915, 910, 905, 900),
#   'windows_ids': (334, 339, 627, 923, 1262, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45, 45],
#   'lags': array([15., 15., 25., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4615., 6310., 8400.]) * ms,
#   'signature': (7, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 919, 903, 915, 907, 905, 900),
#   'windows_ids': (334, 339, 623, 627, 1262, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45, 45],
#   'lags': array([15., 15., 25., 35., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3115., 3135., 6310., 8400.]) * ms,
#   'signature': (7, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 919, 914, 902, 904, 905, 900, 909),
#   'windows_ids': (349, 623, 924, 929, 1262, 1267),
#   'neurons': [45, 45, 31, 45, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 45., 70., 95.]) * ms,
#   'times': array([1745., 3115., 4620., 4645., 6310., 6335.]) * ms,
#   'signature': (8, 6, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 622, 918, 914, 904, 902, 900),
#   'windows_ids': (623, 624, 628, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 70., 90.]) * ms,
#   'times': array([3115., 3120., 3140., 4620., 6310., 8405.]) * ms,
#   'signature': (7, 6, 18),
#   'pvalue': 0.0},
#  {'itemset': (623, 916, 902, 912, 907, 904, 900),
#   'windows_ids': (337, 342, 630, 922, 1265, 1683),
#   'neurons': [45, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 35., 60., 80.]) * ms,
#   'times': array([1685., 1710., 3150., 4610., 6325., 8415.]) * ms,
#   'signature': (7, 6, 16),
#   'pvalue': 0.002},
#  {'itemset': (623, 620, 902, 912, 904, 907, 900),
#   'windows_ids': (337, 342, 630, 924, 1265, 1683),
#   'neurons': [31, 45, 45, 31, 45, 45, 45],
#   'lags': array([ 0., 10., 15., 20., 35., 60.]) * ms,
#   'times': array([1685., 1710., 3150., 4620., 6325., 8415.]) * ms,
#   'signature': (7, 6, 12),
#   'pvalue': 0.002},
#  {'itemset': (623, 914, 902, 904, 909, 907, 900),
#   'windows_ids': (337, 623, 922, 924, 929, 1262),
#   'neurons': [45, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 35., 45., 70.]) * ms,
#   'times': array([1685., 3115., 4610., 4620., 4645., 6310.]) * ms,
#   'signature': (7, 6, 14),
#   'pvalue': 0.003},
#  {'itemset': (626, 917, 620, 903, 912, 905, 907),
#   'windows_ids': (334, 346, 625, 926, 1264, 1678),
#   'neurons': [31, 45, 45, 31, 45, 45, 45],
#   'lags': array([15., 25., 30., 35., 60., 85.]) * ms,
#   'times': array([1670., 1730., 3125., 4630., 6320., 8390.]) * ms,
#   'signature': (7, 6, 17),
#   'pvalue': 0.0},
#  {'itemset': (626, 620, 903, 912, 905, 900, 907),
#   'windows_ids': (334, 346, 625, 926, 1264, 1680),
#   'neurons': [31, 45, 45, 45, 31, 45, 45],
#   'lags': array([ 0., 15., 25., 30., 35., 60.]) * ms,
#   'times': array([1670., 1730., 3125., 4630., 6320., 8400.]) * ms,
#   'signature': (7, 6, 12),
#   'pvalue': 0.002},
#  {'itemset': (626, 620, 903, 901, 900, 905),
#   'windows_ids': (336, 625, 627, 1264, 1266, 1680),
#   'neurons': [31, 45, 45, 45, 45, 31],
#   'lags': array([ 0.,  5., 15., 25., 30.]) * ms,
#   'times': array([1680., 3125., 3135., 6320., 6330., 8400.]) * ms,
#   'signature': (6, 6, 6),
#   'pvalue': 0.014},
#  {'itemset': (621, 916, 620, 902, 912, 907, 900),
#   'windows_ids': (625, 630, 926, 1264, 1265, 1683),
#   'neurons': [31, 45, 31, 45, 45, 45, 45],
#   'lags': array([ 0.,  5., 10., 35., 60., 80.]) * ms,
#   'times': array([3125., 3150., 4630., 6320., 6325., 8415.]) * ms,
#   'signature': (7, 6, 16),
#   'pvalue': 0.002},
#  {'itemset': (629, 916, 902, 912, 907, 900),
#   'windows_ids': (337, 342, 625, 630, 926, 936, 1683),
#   'neurons': [45, 45, 45, 31, 45, 45],
#   'lags': array([10., 35., 45., 60., 80.]) * ms,
#   'times': array([1685., 1710., 3125., 3150., 4630., 4680., 8415.]) * ms,
#   'signature': (6, 7, 16),
#   'pvalue': 0.002},
#  {'itemset': (635, 623, 914, 902, 904, 900),
#   'windows_ids': (337, 623, 624, 929, 1262, 1267, 1681),
#   'neurons': [45, 45, 31, 45, 45, 31],
#   'lags': array([10., 15., 20., 70., 75.]) * ms,
#   'times': array([1685., 3115., 3120., 4645., 6310., 6335., 8405.]) * ms,
#   'signature': (6, 7, 15),
#   'pvalue': 0.004},
#  {'itemset': (624, 622, 903, 901, 905, 900),
#   'windows_ids': (623, 923, 928, 1264, 1266, 1676, 1680),
#   'neurons': [45, 45, 31, 45, 31, 45],
#   'lags': array([ 5., 10., 15., 20., 25.]) * ms,
#   'times': array([3115., 4615., 4640., 6320., 6330., 8380., 8400.]) * ms,
#   'signature': (6, 7, 5),
#   'pvalue': 0.0},
#  {'itemset': (624, 903, 915, 910, 900, 905),
#   'windows_ids': (336, 627, 923, 928, 1262, 1266, 1680),
#   'neurons': [45, 45, 31, 45, 45, 45],
#   'lags': array([15., 20., 25., 50., 75.]) * ms,
#   'times': array([1680., 3135., 4615., 4640., 6310., 6330., 8400.]) * ms,
#   'signature': (6, 7, 15),
#   'pvalue': 0.004},
#  {'itemset': (624, 903, 915, 901, 900, 905),
#   'windows_ids': (336, 623, 627, 923, 928, 1266, 1680),
#   'neurons': [45, 45, 45, 31, 45, 45],
#   'lags': array([ 5., 15., 20., 25., 75.]) * ms,
#   'times': array([1680., 3115., 3135., 4615., 4640., 6330., 8400.]) * ms,
#   'signature': (6, 7, 15),
#   'pvalue': 0.004},
#  {'itemset': (624, 903, 910, 901, 900, 905),
#   'windows_ids': (336, 341, 627, 923, 928, 1266, 1680),
#   'neurons': [45, 45, 45, 31, 45, 45],
#   'lags': array([ 5., 15., 20., 25., 50.]) * ms,
#   'times': array([1680., 1705., 3135., 4615., 4640., 6330., 8400.]) * ms,
#   'signature': (6, 7, 10),
#   'pvalue': 0.007},
#  {'itemset': (628, 623, 902, 904, 907, 900),
#   'windows_ids': (337, 623, 630, 922, 924, 1262, 1677),
#   'neurons': [45, 45, 31, 45, 45, 31],
#   'lags': array([10., 15., 20., 35., 40.]) * ms,
#   'times': array([1685., 3115., 3150., 4610., 4620., 6310., 8385.]) * ms,
#   'signature': (6, 7, 8),
#   'pvalue': 0.004},
#  {'itemset': (628, 622, 902, 907, 905, 900),
#   'windows_ids': (334, 344, 623, 625, 924, 1262, 1264),
#   'neurons': [45, 31, 45, 45, 45, 31],
#   'lags': array([10., 10., 25., 35., 40.]) * ms,
#   'times': array([1670., 1720., 3115., 3125., 4620., 6310., 6320.]) * ms,
#   'signature': (6, 7, 8),
#   'pvalue': 0.004},
#  {'itemset': (623, 626, 919, 903, 900, 915),
#   'windows_ids': (334, 339, 627, 1262, 1677, 1680, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([15., 15., 30., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 6310., 8385., 8400., 8405.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 626, 919, 910, 900, 907),
#   'windows_ids': (334, 339, 627, 924, 1262, 1677, 1680),
#   'neurons': [45, 31, 31, 45, 45, 45],
#   'lags': array([15., 30., 35., 50., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4620., 6310., 8385., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 626, 919, 907, 905, 900),
#   'windows_ids': (334, 339, 627, 924, 929, 1262, 1680),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([15., 25., 30., 35., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4620., 4645., 6310., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 626, 914, 902, 904, 900),
#   'windows_ids': (349, 624, 628, 924, 929, 1262, 1681),
#   'neurons': [45, 45, 31, 45, 31, 45],
#   'lags': array([10., 15., 20., 30., 70.]) * ms,
#   'times': array([1745., 3120., 3140., 4620., 4645., 6310., 8405.]) * ms,
#   'signature': (6, 7, 14),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 903, 915, 910, 900),
#   'windows_ids': (334, 339, 627, 923, 1262, 1677, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 4615., 6310., 8385., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 903, 915, 907, 900),
#   'windows_ids': (334, 339, 623, 627, 1262, 1677, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 35., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3115., 3135., 6310., 8385., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 903, 915, 905, 900),
#   'windows_ids': (334, 339, 623, 627, 923, 1262, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([15., 15., 25., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3115., 3135., 4615., 6310., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 915, 910, 907, 900),
#   'windows_ids': (334, 339, 627, 1262, 1265, 1677, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([15., 35., 50., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3135., 6310., 6325., 8385., 8400.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 914, 902, 904, 900, 909),
#   'windows_ids': (349, 623, 924, 929, 1262, 1267, 1681),
#   'neurons': [45, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 45., 70., 95.]) * ms,
#   'times': array([1745., 3115., 4620., 4645., 6310., 6335., 8405.]) * ms,
#   'signature': (7, 7, 19),
#   'pvalue': 0.0},
#  {'itemset': (623, 919, 914, 902, 905, 900),
#   'windows_ids': (339, 349, 623, 924, 929, 1262, 1267),
#   'neurons': [45, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 25., 70., 95.]) * ms,
#   'times': array([1695., 1745., 3115., 4620., 4645., 6310., 6335.]) * ms,
#   'signature': (6, 7, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 622, 914, 902, 904, 909, 900),
#   'windows_ids': (349, 623, 628, 922, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45, 45],
#   'lags': array([10., 10., 15., 20., 45., 70.]) * ms,
#   'times': array([1745., 3115., 3140., 4610., 4620., 6310., 8405.]) * ms,
#   'signature': (7, 7, 14),
#   'pvalue': 0.0},
#  {'itemset': (623, 916, 912, 904, 907, 900),
#   'windows_ids': (337, 342, 630, 922, 1265, 1680, 1683),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([15., 20., 35., 60., 80.]) * ms,
#   'times': array([1685., 1710., 3150., 4610., 6325., 8400., 8415.]) * ms,
#   'signature': (6, 7, 16),
#   'pvalue': 0.002},
#  {'itemset': (623, 914, 902, 904, 909, 905, 900),
#   'windows_ids': (337, 349, 623, 924, 929, 1262, 1267),
#   'neurons': [45, 45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 20., 25., 45., 70.]) * ms,
#   'times': array([1685., 1745., 3115., 4620., 4645., 6310., 6335.]) * ms,
#   'signature': (7, 7, 14),
#   'pvalue': 0.0},
#  {'itemset': (626, 622, 914, 902, 909, 900),
#   'windows_ids': (349, 628, 632, 924, 1262, 1681, 1690),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 30., 45., 70.]) * ms,
#   'times': array([1745., 3140., 3160., 4620., 6310., 8405., 8450.]) * ms,
#   'signature': (6, 7, 14),
#   'pvalue': 0.003},
#  {'itemset': (626, 622, 914, 909, 905, 900),
#   'windows_ids': (349, 632, 924, 1262, 1266, 1676, 1690),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([10., 25., 30., 45., 70.]) * ms,
#   'times': array([1745., 3160., 4620., 6310., 6330., 8380., 8450.]) * ms,
#   'signature': (6, 7, 14),
#   'pvalue': 0.003},
#  {'itemset': (626, 620, 903, 907, 905, 900),
#   'windows_ids': (334, 346, 625, 627, 926, 1264, 1680),
#   'neurons': [31, 45, 45, 45, 31, 45],
#   'lags': array([ 0., 15., 25., 30., 35.]) * ms,
#   'times': array([1670., 1730., 3125., 3135., 4630., 6320., 8400.]) * ms,
#   'signature': (6, 7, 7),
#   'pvalue': 0.003},
#  {'itemset': (626, 903, 915, 910, 905, 900),
#   'windows_ids': (334, 336, 339, 627, 1262, 1266, 1680),
#   'neurons': [45, 45, 45, 31, 45, 45],
#   'lags': array([15., 25., 30., 50., 75.]) * ms,
#   'times': array([1670., 1680., 1695., 3135., 6310., 6330., 8400.]) * ms,
#   'signature': (6, 7, 15),
#   'pvalue': 0.004},
#  {'itemset': (621, 916, 620, 902, 912, 900),
#   'windows_ids': (625, 626, 630, 926, 1264, 1265, 1683),
#   'neurons': [31, 45, 31, 45, 45, 45],
#   'lags': array([ 0.,  5., 10., 60., 80.]) * ms,
#   'times': array([3125., 3130., 3150., 4630., 6320., 6325., 8415.]) * ms,
#   'signature': (6, 7, 16),
#   'pvalue': 0.002},
#  {'itemset': (622, 903, 915, 910, 905, 900),
#   'windows_ids': (334, 923, 928, 933, 1262, 1266, 1680),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([10., 15., 25., 50., 75.]) * ms,
#   'times': array([1670., 4615., 4640., 4665., 6310., 6330., 8400.]) * ms,
#   'signature': (6, 7, 15),
#   'pvalue': 0.004},
#  {'itemset': (622, 914, 902, 909, 905, 900),
#   'windows_ids': (344, 349, 623, 632, 924, 1262, 1690),
#   'neurons': [45, 31, 45, 45, 45, 45],
#   'lags': array([10., 10., 25., 45., 70.]) * ms,
#   'times': array([1720., 1745., 3115., 3160., 4620., 6310., 8450.]) * ms,
#   'signature': (6, 7, 14),
#   'pvalue': 0.003},
#  {'itemset': (917, 620, 902, 912, 900, 907),
#   'windows_ids': (334, 337, 351, 625, 926, 1264, 1683),
#   'neurons': [31, 45, 45, 45, 45, 45],
#   'lags': array([ 0., 10., 35., 60., 85.]) * ms,
#   'times': array([1670., 1685., 1755., 3125., 4630., 6320., 8415.]) * ms,
#   'signature': (6, 7, 17),
#   'pvalue': 0.001},
#  {'itemset': (623, 622, 914, 902, 904, 900),
#   'windows_ids': (349, 623, 624, 628, 922, 924, 1262, 1681),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 70.]) * ms,
#   'times': array([1745., 3115., 3120., 3140., 4610., 4620., 6310., 8405.]) * ms,
#   'signature': (6, 8, 14),
#   'pvalue': 0.0},
#  {'itemset': (623, 622, 902, 904, 909, 900),
#   'windows_ids': (349, 623, 628, 922, 924, 1262, 1681, 1683),
#   'neurons': [45, 31, 45, 31, 45, 45],
#   'lags': array([10., 10., 15., 20., 45.]) * ms,
#   'times': array([1745., 3115., 3140., 4610., 4620., 6310., 8405., 8415.]) * ms,
#   'signature': (6, 8, 9),
#   'pvalue': 0.0},
#  {'itemset': (623, 902, 904, 909, 907, 900),
#   'windows_ids': (337, 342, 623, 922, 924, 929, 1262, 1683),
#   'neurons': [45, 45, 31, 45, 45, 45],
#   'lags': array([10., 15., 20., 35., 45.]) * ms,
#   'times': array([1685., 1710., 3115., 4610., 4620., 4645., 6310., 8415.]) * ms,
#   'signature': (6, 8, 9),
#   'pvalue': 0.0},
#  {'itemset': (621, 917, 902, 907, 900),
#   'windows_ids': (351, 625, 926, 929, 931, 1264, 1269, 1683),
#   'neurons': [45, 31, 45, 45, 45],
#   'lags': array([ 5., 10., 35., 85.]) * ms,
#   'times': array([1755., 3125., 4630., 4645., 4655., 6320., 6345., 8415.]) * ms,
#   'signature': (5, 8, 17),
#   'pvalue': 0.01},
#  {'itemset': (621, 917, 902, 905, 900),
#   'windows_ids': (625, 926, 929, 931, 1264, 1267, 1275, 1679),
#   'neurons': [45, 31, 45, 45, 45],
#   'lags': array([ 5., 10., 25., 85.]) * ms,
#   'times': array([3125., 4630., 4645., 4655., 6320., 6335., 6375., 8395.]) * ms,
#   'signature': (5, 8, 17),
#   'pvalue': 0.01},
#  {'itemset': (621, 620, 902, 912, 907, 900),
#   'windows_ids': (351, 625, 630, 924, 926, 1264, 1265, 1683),
#   'neurons': [31, 45, 31, 45, 45, 45],
#   'lags': array([ 0.,  5., 10., 35., 60.]) * ms,
#   'times': array([1755., 3125., 3150., 4620., 4630., 6320., 6325., 8415.]) * ms,
#   'signature': (6, 8, 12),
#   'pvalue': 0.001},
#  {'itemset': (917, 620, 902, 912, 907),
#   'windows_ids': (334, 337, 351, 625, 926, 1264, 1678, 1683),
#   'neurons': [31, 45, 45, 45, 45],
#   'lags': array([10., 35., 60., 85.]) * ms,
#   'times': array([1670., 1685., 1755., 3125., 4630., 6320., 8390., 8415.]) * ms,
#   'signature': (5, 8, 17),
#   'pvalue': 0.01},
#  {'itemset': (917, 620, 912, 907, 900),
#   'windows_ids': (334, 337, 346, 351, 625, 926, 1264, 1683),
#   'neurons': [31, 45, 45, 45, 45],
#   'lags': array([ 0., 35., 60., 85.]) * ms,
#   'times': array([1670., 1685., 1730., 1755., 3125., 4630., 6320., 8415.]) * ms,
#   'signature': (5, 8, 17),
#   'pvalue': 0.01},
#  {'itemset': (916, 620, 902, 912, 907, 900),
#   'windows_ids': (337, 342, 625, 630, 926, 1264, 1265, 1683),
#   'neurons': [31, 45, 45, 45, 45, 45],
#   'lags': array([ 0., 10., 35., 60., 80.]) * ms,
#   'times': array([1685., 1710., 3125., 3150., 4630., 6320., 6325., 8415.]) * ms,
#   'signature': (6, 8, 16),
#   'pvalue': 0.0},
#  {'itemset': (624, 903, 915, 905, 900),
#   'windows_ids': (336, 623, 627, 923, 928, 931, 1262, 1266, 1680),
#   'neurons': [45, 45, 31, 45, 45],
#   'lags': array([15., 20., 25., 75.]) * ms,
#   'times': array([1680., 3115., 3135., 4615., 4640., 4655., 6310., 6330., 8400.]) * ms,
#   'signature': (5, 9, 15),
#   'pvalue': 0.006},
#  {'itemset': (624, 903, 910, 900, 905),
#   'windows_ids': (336, 341, 627, 923, 926, 928, 1262, 1266, 1680),
#   'neurons': [45, 45, 31, 45, 45],
#   'lags': array([15., 20., 25., 50.]) * ms,
#   'times': array([1680., 1705., 3135., 4615., 4630., 4640., 6310., 6330., 8400.]) * ms,
#   'signature': (5, 9, 10),
#   'pvalue': 0.006},
#  {'itemset': (630, 623, 902, 904, 900),
#   'windows_ids': (342, 623, 624, 628, 630, 922, 1262, 1267, 1677),
#   'neurons': [45, 45, 31, 45, 31],
#   'lags': array([10., 15., 20., 50.]) * ms,
#   'times': array([1710., 3115., 3120., 3140., 3150., 4610., 6310., 6335., 8385.]) * ms,
#   'signature': (5, 9, 10),
#   'pvalue': 0.006},
#  {'itemset': (628, 623, 902, 907, 900),
#   'windows_ids': (334, 337, 623, 630, 922, 924, 1262, 1269, 1677),
#   'neurons': [45, 45, 31, 45, 31],
#   'lags': array([10., 15., 35., 40.]) * ms,
#   'times': array([1670., 1685., 3115., 3150., 4610., 4620., 6310., 6345., 8385.]) * ms,
#   'signature': (5, 9, 8),
#   'pvalue': 0.012},
#  {'itemset': (628, 622, 902, 907, 900),
#   'windows_ids': (334, 344, 623, 625, 922, 924, 936, 1262, 1264),
#   'neurons': [45, 31, 45, 45, 31],
#   'lags': array([10., 10., 35., 40.]) * ms,
#   'times': array([1670., 1720., 3115., 3125., 4610., 4620., 4680., 6310., 6320.]) * ms,
#   'signature': (5, 9, 8),
#   'pvalue': 0.012},
#  {'itemset': (623, 626, 902, 904, 900),
#   'windows_ids': (349, 624, 628, 924, 929, 1262, 1677, 1679, 1681),
#   'neurons': [45, 45, 31, 45, 31],
#   'lags': array([10., 15., 20., 30.]) * ms,
#   'times': array([1745., 3120., 3140., 4620., 4645., 6310., 8385., 8395., 8405.]) * ms,
#   'signature': (5, 9, 6),
#   'pvalue': 0.006},
#  {'itemset': (623, 919, 903, 915, 900),
#   'windows_ids': (334, 339, 623, 627, 923, 1262, 1677, 1680, 1681),
#   'neurons': [45, 31, 45, 45, 45],
#   'lags': array([15., 15., 75., 95.]) * ms,
#   'times': array([1670., 1695., 3115., 3135., 4615., 6310., 8385., 8400., 8405.]) * ms,
#   'signature': (5, 9, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 919, 902, 904, 900),
#   'windows_ids': (349, 623, 924, 929, 1262, 1265, 1267, 1677, 1681),
#   'neurons': [45, 45, 31, 45, 45],
#   'lags': array([10., 15., 20., 95.]) * ms,
#   'times': array([1745., 3115., 4620., 4645., 6310., 6325., 6335., 8385., 8405.]) * ms,
#   'signature': (5, 9, 19),
#   'pvalue': 0.003},
#  {'itemset': (623, 622, 902, 904, 900),
#   'windows_ids': (349, 623, 624, 628, 922, 924, 1262, 1681, 1683),
#   'neurons': [45, 31, 45, 31, 45],
#   'lags': array([10., 10., 15., 20.]) * ms,
#   'times': array([1745., 3115., 3120., 3140., 4610., 4620., 6310., 8405., 8415.]) * ms,
#   'signature': (5, 9, 4),
#   'pvalue': 0.003},
#  {'itemset': (623, 622, 904, 909, 900),
#   'windows_ids': (349, 623, 628, 637, 922, 924, 1262, 1681, 1683),
#   'neurons': [45, 31, 31, 45, 45],
#   'lags': array([10., 15., 20., 45.]) * ms,
#   'times': array([1745., 3115., 3140., 3185., 4610., 4620., 6310., 8405., 8415.]) * ms,
#   'signature': (5, 9, 9),
#   'pvalue': 0.004},
#  {'itemset': (626, 622, 914, 909, 900),
#   'windows_ids': (349, 628, 632, 924, 1262, 1266, 1676, 1681, 1690),
#   'neurons': [45, 31, 31, 45, 45],
#   'lags': array([10., 30., 45., 70.]) * ms,
#   'times': array([1745., 3140., 3160., 4620., 6310., 6330., 8380., 8405., 8450.]) * ms,
#   'signature': (5, 9, 14),
#   'pvalue': 0.001},
#  {'itemset': (626, 620, 903, 905, 900),
#   'windows_ids': (334, 336, 346, 625, 627, 926, 1264, 1266, 1680),
#   'neurons': [31, 45, 45, 45, 31],
#   'lags': array([ 0., 15., 25., 30.]) * ms,
#   'times': array([1670., 1680., 1730., 3125., 3135., 4630., 6320., 6330., 8400.]) * ms,
#   'signature': (5, 9, 6),
#   'pvalue': 0.006},
#  {'itemset': (626, 620, 910, 905, 900),
#   'windows_ids': (334, 336, 627, 924, 926, 938, 1266, 1276, 1680),
#   'neurons': [31, 45, 45, 31, 45],
#   'lags': array([ 0., 25., 30., 50.]) * ms,
#   'times': array([1670., 1680., 3135., 4620., 4630., 4690., 6330., 6380., 8400.]) * ms,
#   'signature': (5, 9, 10),
#   'pvalue': 0.006},
#  {'itemset': (621, 620, 902, 907, 900),
#   'windows_ids': (351, 625, 630, 924, 926, 1264, 1265, 1683, 1685),
#   'neurons': [31, 45, 31, 45, 45],
#   'lags': array([ 0.,  5., 10., 35.]) * ms,
#   'times': array([1755., 3125., 3150., 4620., 4630., 6320., 6325., 8415., 8425.]) * ms,
#   'signature': (5, 9, 7),
#   'pvalue': 0.006},
#  {'itemset': (621, 902, 907, 905, 900),
#   'windows_ids': (339, 344, 625, 924, 926, 929, 931, 1264, 1685),
#   'neurons': [45, 31, 45, 45, 45],
#   'lags': array([ 5., 10., 25., 35.]) * ms,
# ...
#          6330., 8400., 8425., 8450.]) * ms,
#   'signature': (4, 13, 10),
#   'pvalue': 0.0},
#  {'itemset': (624, 903, 905, 900),
#   'windows_ids': (336,
#    341,
#    623,
#    627,
#    923,
#    926,
#    928,
#    931,
#    1262,
#    1264,
#    1266,
#    1272,
#    1676,
#    1680),
#   'neurons': [45, 45, 31, 45],
#   'lags': array([15., 20., 25.]) * ms,
#   'times': array([1680., 1705., 3115., 3135., 4615., 4630., 4640., 4655., 6310.,
#          6320., 6330., 6360., 8380., 8400.]) * ms,
#   'signature': (4, 14, 5),
#   'pvalue': 0.001},
#  {'itemset': (623, 919, 900),
#   'windows_ids': (334,
#    339,
#    349,
#    623,
#    627,
#    923,
#    924,
#    929,
#    1262,
#    1265,
#    1267,
#    1677,
#    1680,
#    1681),
#   'neurons': [45, 31, 45],
#   'lags': array([15., 95.]) * ms,
#   'times': array([1670., 1695., 1745., 3115., 3135., 4615., 4620., 4645., 6310.,
#          6325., 6335., 8385., 8400., 8405.]) * ms,
#   'signature': (3, 14, 19),
#   'pvalue': 0.008},
#  {'itemset': (623, 902, 907, 900),
#   'windows_ids': (334,
#    337,
#    339,
#    342,
#    623,
#    630,
#    922,
#    924,
#    929,
#    1262,
#    1265,
#    1269,
#    1677,
#    1683),
#   'neurons': [45, 45, 31, 45],
#   'lags': array([10., 15., 35.]) * ms,
#   'times': array([1670., 1685., 1695., 1710., 3115., 3150., 4610., 4620., 4645.,
#          6310., 6325., 6345., 8385., 8415.]) * ms,
#   'signature': (4, 14, 7),
#   'pvalue': 0.001},
#  {'itemset': (623, 904, 909, 900),
#   'windows_ids': (333,
#    337,
#    342,
#    349,
#    623,
#    628,
#    637,
#    922,
#    924,
#    929,
#    1262,
#    1267,
#    1681,
#    1683),
#   'neurons': [45, 31, 45, 45],
#   'lags': array([15., 20., 45.]) * ms,
#   'times': array([1665., 1685., 1710., 1745., 3115., 3140., 3185., 4610., 4620.,
#          4645., 6310., 6335., 8405., 8415.]) * ms,
#   'signature': (4, 14, 9),
#   'pvalue': 0.0},
#  {'itemset': (626, 910, 905, 900),
#   'windows_ids': (334,
#    336,
#    339,
#    627,
#    632,
#    924,
#    926,
#    938,
#    1262,
#    1266,
#    1271,
#    1276,
#    1680,
#    1690),
#   'neurons': [45, 45, 31, 45],
#   'lags': array([25., 30., 50.]) * ms,
#   'times': array([1670., 1680., 1695., 3135., 3160., 4620., 4630., 4690., 6310.,
#          6330., 6355., 6380., 8400., 8450.]) * ms,
#   'signature': (4, 14, 10),
#   'pvalue': 0.0},
#  {'itemset': (622, 909, 905, 900),
#   'windows_ids': (344,
#    349,
#    623,
#    625,
#    632,
#    637,
#    924,
#    933,
#    943,
#    1262,
#    1266,
#    1275,
#    1676,
#    1690),
#   'neurons': [45, 31, 45, 45],
#   'lags': array([10., 25., 45.]) * ms,
#   'times': array([1720., 1745., 3115., 3125., 3160., 3185., 4620., 4665., 4715.,
#          6310., 6330., 6375., 8380., 8450.]) * ms,
#   'signature': (4, 14, 9),
#   'pvalue': 0.0},
#  {'itemset': (621, 902, 907, 900),
#   'windows_ids': (339,
#    344,
#    351,
#    625,
#    630,
#    924,
#    926,
#    929,
#    931,
#    1264,
#    1265,
#    1269,
#    1677,
#    1683,
#    1685),
#   'neurons': [45, 31, 45, 45],
#   'lags': array([ 5., 10., 35.]) * ms,
#   'times': array([1695., 1720., 1755., 3125., 3150., 4620., 4630., 4645., 4655.,
#          6320., 6325., 6345., 8385., 8415., 8425.]) * ms,
#   'signature': (4, 15, 7),
#   'pvalue': 0.0},
#  {'itemset': (916, 620, 912),
#   'windows_ids': (337,
#    342,
#    614,
#    625,
#    626,
#    630,
#    926,
#    930,
#    1264,
#    1265,
#    1268,
#    1665,
#    1680,
#    1683,
#    1684),
#   'neurons': [31, 45, 45],
#   'lags': array([60., 80.]) * ms,
#   'times': array([1685., 1710., 3070., 3125., 3130., 3150., 4630., 4650., 6320.,
#          6325., 6340., 8325., 8400., 8415., 8420.]) * ms,
#   'signature': (3, 15, 16),
#   'pvalue': 0.014},
#  {'itemset': (620, 912, 907, 900),
#   'windows_ids': (334,
#    337,
#    342,
#    346,
#    351,
#    625,
#    630,
#    634,
#    924,
#    926,
#    1264,
#    1265,
#    1680,
#    1683,
#    1692),
#   'neurons': [31, 45, 45, 45],
#   'lags': array([ 0., 35., 60.]) * ms,
#   'times': array([1670., 1685., 1710., 1730., 1755., 3125., 3150., 3170., 4620.,
#          4630., 6320., 6325., 8400., 8415., 8460.]) * ms,
#   'signature': (4, 15, 12),
#   'pvalue': 0.0},
#  {'itemset': (621, 917, 900),
#   'windows_ids': (336,
#    341,
#    351,
#    624,
#    625,
#    638,
#    926,
#    929,
#    931,
#    1264,
#    1267,
#    1269,
#    1275,
#    1276,
#    1679,
#    1683),
#   'neurons': [45, 31, 45],
#   'lags': array([ 5., 85.]) * ms,
#   'times': array([1680., 1705., 1755., 3120., 3125., 3190., 4630., 4645., 4655.,
#          6320., 6335., 6345., 6375., 6380., 8395., 8415.]) * ms,
#   'signature': (3, 16, 17),
#   'pvalue': 0.002},
#  {'itemset': (623, 902, 904, 900),
#   'windows_ids': (337,
#    342,
#    349,
#    623,
#    624,
#    628,
#    630,
#    922,
#    924,
#    929,
#    1262,
#    1265,
#    1267,
#    1677,
#    1679,
#    1681,
#    1683),
#   'neurons': [45, 45, 31, 45],
#   'lags': array([10., 15., 20.]) * ms,
#   'times': array([1685., 1710., 1745., 3115., 3120., 3140., 3150., 4610., 4620.,
#          4645., 6310., 6325., 6335., 8385., 8395., 8405., 8415.]) * ms,
#   'signature': (4, 17, 4),
#   'pvalue': 0.0},
#  {'itemset': (620, 912, 907),
#   'windows_ids': (334,
#    337,
#    342,
#    346,
#    351,
#    625,
#    630,
#    634,
#    924,
#    926,
#    1264,
#    1265,
#    1268,
#    1678,
#    1680,
#    1683,
#    1692),
#   'neurons': [31, 45, 45],
#   'lags': array([35., 60.]) * ms,
#   'times': array([1670., 1685., 1710., 1730., 1755., 3125., 3150., 3170., 4620.,
#          4630., 6320., 6325., 6340., 8390., 8400., 8415., 8460.]) * ms,
#   'signature': (3, 17, 12),
#   'pvalue': 0.011},
#  {'itemset': (626, 910, 900),
#   'windows_ids': (334,
#    336,
#    339,
#    624,
#    627,
#    628,
#    632,
#    924,
#    926,
#    938,
#    942,
#    1262,
#    1266,
#    1271,
#    1276,
#    1677,
#    1680,
#    1690),
#   'neurons': [45, 31, 45],
#   'lags': array([30., 50.]) * ms,
#   'times': array([1670., 1680., 1695., 3120., 3135., 3140., 3160., 4620., 4630.,
#          4690., 4710., 6310., 6330., 6355., 6380., 8385., 8400., 8450.]) * ms,
#   'signature': (3, 18, 10),
#   'pvalue': 0.007},
#  {'itemset': (626, 904, 900),
#   'windows_ids': (349,
#    624,
#    628,
#    634,
#    924,
#    929,
#    938,
#    942,
#    1262,
#    1271,
#    1276,
#    1676,
#    1677,
#    1679,
#    1680,
#    1681,
#    1695,
#    1696),
#   'neurons': [45, 45, 31],
#   'lags': array([20., 30.]) * ms,
#   'times': array([1745., 3120., 3140., 3170., 4620., 4645., 4690., 4710., 6310.,
#          6355., 6380., 8380., 8385., 8395., 8400., 8405., 8475., 8480.]) * ms,
#   'signature': (3, 18, 6),
#   'pvalue': 0.015},
#  {'itemset': (621, 901, 900),
#   'windows_ids': (333,
#    336,
#    341,
#    624,
#    625,
#    626,
#    637,
#    641,
#    923,
#    1264,
#    1265,
#    1271,
#    1275,
#    1276,
#    1679,
#    1683,
#    1684,
#    1695),
#   'neurons': [45, 31, 45],
#   'lags': array([5., 5.]) * ms,
#   'times': array([1665., 1680., 1705., 3120., 3125., 3130., 3185., 3205., 4615.,
#          6320., 6325., 6355., 6375., 6380., 8395., 8415., 8420., 8475.]) * ms,
#   'signature': (3, 18, 1),
#   'pvalue': 0.016},
#  {'itemset': (622, 910, 900),
#   'windows_ids': (334,
#    344,
#    353,
#    624,
#    628,
#    632,
#    923,
#    924,
#    928,
#    933,
#    936,
#    942,
#    1262,
#    1266,
#    1680,
#    1685,
#    1690,
#    1700),
#   'neurons': [45, 31, 45],
#   'lags': array([10., 50.]) * ms,
#   'times': array([1670., 1720., 1765., 3120., 3140., 3160., 4615., 4620., 4640.,
#          4665., 4680., 4710., 6310., 6330., 8400., 8425., 8450., 8500.]) * ms,
#   'signature': (3, 18, 10),
#   'pvalue': 0.007},
#  {'itemset': (622, 909, 900),
#   'windows_ids': (344,
#    349,
#    623,
#    625,
#    628,
#    632,
#    637,
#    922,
#    924,
#    933,
#    943,
#    1262,
#    1266,
#    1275,
#    1676,
#    1681,
#    1683,
#    1690),
#   'neurons': [45, 31, 45],
#   'lags': array([10., 45.]) * ms,
#   'times': array([1720., 1745., 3115., 3125., 3140., 3160., 3185., 4610., 4620.,
#          4665., 4715., 6310., 6330., 6375., 8380., 8405., 8415., 8450.]) * ms,
#   'signature': (3, 18, 9),
#   'pvalue': 0.009},
#  {'itemset': (620, 908, 903),
#   'windows_ids': (334,
#    336,
#    346,
#    355,
#    634,
#    638,
#    925,
#    926,
#    930,
#    935,
#    1264,
#    1268,
#    1272,
#    1682,
#    1684,
#    1687,
#    1692,
#    1696),
#   'neurons': [31, 45, 45],
#   'lags': array([15., 40.]) * ms,
#   'times': array([1670., 1680., 1730., 1775., 3170., 3190., 4625., 4630., 4650.,
#          4675., 6320., 6340., 6360., 8410., 8420., 8435., 8460., 8480.]) * ms,
#   'signature': (3, 18, 8),
#   'pvalue': 0.013},
#  {'itemset': (620, 907, 900),
#   'windows_ids': (334,
#    337,
#    342,
#    346,
#    351,
#    625,
#    627,
#    630,
#    634,
#    924,
#    926,
#    1264,
#    1265,
#    1277,
#    1680,
#    1683,
#    1685,
#    1692),
#   'neurons': [31, 45, 45],
#   'lags': array([ 0., 35.]) * ms,
#   'times': array([1670., 1685., 1710., 1730., 1755., 3125., 3135., 3150., 3170.,
#          4620., 4630., 6320., 6325., 6385., 8400., 8415., 8425., 8460.]) * ms,
#   'signature': (3, 18, 7),
#   'pvalue': 0.012},
#  {'itemset': (620, 912, 900),
#   'windows_ids': (334,
#    337,
#    342,
#    346,
#    351,
#    625,
#    626,
#    630,
#    634,
#    924,
#    926,
#    1264,
#    1265,
#    1272,
#    1680,
#    1683,
#    1684,
#    1687,
#    1692),
#   'neurons': [31, 45, 45],
#   'lags': array([ 0., 60.]) * ms,
#   'times': array([1670., 1685., 1710., 1730., 1755., 3125., 3130., 3150., 3170.,
#          4620., 4630., 6320., 6325., 6360., 8400., 8415., 8420., 8435.,
#          8460.]) * ms,
#   'signature': (3, 19, 12),
#   'pvalue': 0.002},
#  {'itemset': (623, 902, 900),
#   'windows_ids': (334,
#    337,
#    339,
#    342,
#    349,
#    623,
#    624,
#    628,
#    630,
#    922,
#    924,
#    929,
#    1262,
#    1265,
#    1267,
#    1269,
#    1677,
#    1679,
#    1681,
#    1683),
#   'neurons': [45, 45, 31],
#   'lags': array([10., 15.]) * ms,
#   'times': array([1670., 1685., 1695., 1710., 1745., 3115., 3120., 3140., 3150.,
#          4610., 4620., 4645., 6310., 6325., 6335., 6345., 8385., 8395.,
#          8405., 8415.]) * ms,
#   'signature': (3, 20, 3),
#   'pvalue': 0.005},
#  {'itemset': (622, 901, 900),
#   'windows_ids': (353,
#    623,
#    624,
#    625,
#    637,
#    922,
#    923,
#    928,
#    933,
#    942,
#    1264,
#    1266,
#    1275,
#    1280,
#    1292,
#    1676,
#    1680,
#    1683,
#    1684,
#    1699),
#   'neurons': [45, 45, 31],
#   'lags': array([ 5., 10.]) * ms,
#   'times': array([1765., 3115., 3120., 3125., 3185., 4610., 4615., 4640., 4665.,
#          4710., 6320., 6330., 6375., 6400., 6460., 8380., 8400., 8415.,
#          8420., 8495.]) * ms,
#   'signature': (3, 20, 2),
#   'pvalue': 0.002},
#  {'itemset': (623, 904, 900),
#   'windows_ids': (333,
#    337,
#    342,
#    349,
#    623,
#    624,
#    628,
#    630,
#    637,
#    922,
#    924,
#    929,
#    942,
#    1262,
#    1265,
#    1267,
#    1677,
#    1679,
#    1680,
#    1681,
#    1683),
#   'neurons': [45, 31, 45],
#   'lags': array([15., 20.]) * ms,
#   'times': array([1665., 1685., 1710., 1745., 3115., 3120., 3140., 3150., 3185.,
#          4610., 4620., 4645., 4710., 6310., 6325., 6335., 8385., 8395.,
#          8400., 8405., 8415.]) * ms,
#   'signature': (3, 21, 4),
#   'pvalue': 0.004},
#  {'itemset': (626, 905, 900),
#   'windows_ids': (334,
#    336,
#    339,
#    346,
#    349,
#    625,
#    627,
#    632,
#    924,
#    926,
#    929,
#    938,
#    1262,
#    1264,
#    1266,
#    1271,
#    1276,
#    1676,
#    1679,
#    1680,
#    1690,
#    1695),
#   'neurons': [45, 45, 31],
#   'lags': array([25., 30.]) * ms,
#   'times': array([1670., 1680., 1695., 1730., 1745., 3125., 3135., 3160., 4620.,
#          4630., 4645., 4690., 6310., 6320., 6330., 6355., 6380., 8380.,
#          8395., 8400., 8450., 8475.]) * ms,
#   'signature': (3, 22, 6),
#   'pvalue': 0.0},
#  {'itemset': (622, 905, 900),
#   'windows_ids': (334,
#    344,
#    349,
#    353,
#    623,
#    625,
#    632,
#    637,
#    923,
#    924,
#    928,
#    933,
#    943,
#    1262,
#    1264,
#    1266,
#    1275,
#    1676,
#    1680,
#    1685,
#    1690,
#    1699),
#   'neurons': [45, 31, 45],
#   'lags': array([10., 25.]) * ms,
#   'times': array([1670., 1720., 1745., 1765., 3115., 3125., 3160., 3185., 4615.,
#          4620., 4640., 4665., 4715., 6310., 6320., 6330., 6375., 8380.,
#          8400., 8425., 8450., 8495.]) * ms,
#   'signature': (3, 22, 5),
#   'pvalue': 0.0},
#  {'itemset': (916, 620),
#   'windows_ids': (337,
#    342,
#    352,
#    614,
#    625,
#    626,
#    630,
#    639,
#    926,
#    927,
#    930,
#    932,
#    1264,
#    1265,
#    1268,
#    1270,
#    1276,
#    1277,
#    1665,
#    1680,
#    1683,
#    1684),
#   'neurons': [31, 45],
#   'lags': array([80.]) * ms,
#   'times': array([1685., 1710., 1760., 3070., 3125., 3130., 3150., 3195., 4630.,
#          4635., 4650., 4660., 6320., 6325., 6340., 6350., 6380., 6385.,
#          8325., 8400., 8415., 8420.]) * ms,
#   'signature': (2, 22, 16),
#   'pvalue': 0.019},
#  {'itemset': (621, 905, 900),
#   'windows_ids': (336,
#    339,
#    341,
#    344,
#    625,
#    632,
#    637,
#    641,
#    923,
#    924,
#    926,
#    929,
#    931,
#    943,
#    1264,
#    1267,
#    1271,
#    1275,
#    1276,
#    1281,
#    1679,
#    1685,
#    1695),
#   'neurons': [45, 31, 45],
#   'lags': array([ 5., 25.]) * ms,
#   'times': array([1680., 1695., 1705., 1720., 3125., 3160., 3185., 3205., 4615.,
#          4620., 4630., 4645., 4655., 4715., 6320., 6335., 6355., 6375.,
#          6380., 6405., 8395., 8425., 8475.]) * ms,
#   'signature': (3, 23, 5),
#   'pvalue': 0.0},
#  {'itemset': (621, 902, 900),
#   'windows_ids': (339,
#    344,
#    351,
#    624,
#    625,
#    626,
#    630,
#    632,
#    924,
#    926,
#    929,
#    931,
#    934,
#    1264,
#    1265,
#    1267,
#    1269,
#    1275,
#    1293,
#    1677,
#    1679,
#    1681,
#    1683,
#    1685),
#   'neurons': [45, 31, 45],
#   'lags': array([ 5., 10.]) * ms,
#   'times': array([1695., 1720., 1755., 3120., 3125., 3130., 3150., 3160., 4620.,
#          4630., 4645., 4655., 4670., 6320., 6325., 6335., 6345., 6375.,
#          6465., 8385., 8395., 8405., 8415., 8425.]) * ms,
#   'signature': (3, 24, 2),
#   'pvalue': 0.0},
#  {'itemset': (620, 912),
#   'windows_ids': (334,
#    337,
#    342,
#    345,
#    346,
#    351,
#    614,
#    625,
#    626,
#    630,
#    634,
#    924,
#    926,
#    930,
#    1264,
#    1265,
#    1268,
#    1272,
#    1665,
#    1678,
#    1680,
#    1683,
#    1684,
#    1687,
#    1692),
#   'neurons': [31, 45],
#   'lags': array([60.]) * ms,
#   'times': array([1670., 1685., 1710., 1725., 1730., 1755., 3070., 3125., 3130.,
#          3150., 3170., 4620., 4630., 4650., 6320., 6325., 6340., 6360.,
#          8325., 8390., 8400., 8415., 8420., 8435., 8460.]) * ms,
#   'signature': (2, 25, 12),
#   'pvalue': 0.019},
#  {'itemset': (626, 900),
#   'windows_ids': (334,
#    336,
#    339,
#    346,
#    349,
#    624,
#    625,
#    627,
#    628,
#    632,
#    634,
#    924,
#    926,
#    929,
#    938,
#    942,
#    1262,
#    1264,
#    1266,
#    1271,
#    1276,
#    1676,
#    1677,
#    1679,
#    1680,
#    1681,
#    1690,
#    1695,
#    1696),
#   'neurons': [45, 31],
#   'lags': array([30.]) * ms,
#   'times': array([1670., 1680., 1695., 1730., 1745., 3120., 3125., 3135., 3140.,
#          3160., 3170., 4620., 4630., 4645., 4690., 4710., 6310., 6320.,
#          6330., 6355., 6380., 8380., 8385., 8395., 8400., 8405., 8450.,
#          8475., 8480.]) * ms,
#   'signature': (2, 29, 6),
#   'pvalue': 0.007},
#  {'itemset': (622, 900),
#   'windows_ids': (334,
#    344,
#    349,
#    353,
#    623,
#    624,
#    625,
#    628,
#    632,
#    637,
#    638,
#    922,
#    923,
#    924,
#    928,
#    933,
#    936,
#    942,
#    943,
#    946,
#    1262,
#    1264,
#    1266,
#    1275,
#    1280,
#    1292,
#    1676,
#    1680,
#    1681,
#    1683,
#    1684,
#    1685,
#    1690,
#    1699,
#    1700),
#   'neurons': [45, 31],
#   'lags': array([10.]) * ms,
#   'times': array([1670., 1720., 1745., 1765., 3115., 3120., 3125., 3140., 3160.,
#          3185., 3190., 4610., 4615., 4620., 4640., 4665., 4680., 4710.,
#          4715., 4730., 6310., 6320., 6330., 6375., 6400., 6460., 8380.,
#          8400., 8405., 8415., 8420., 8425., 8450., 8495., 8500.]) * ms,
#   'signature': (2, 35, 2),
#   'pvalue': 0.006},
#  {'itemset': (621, 900),
#   'windows_ids': (333,
#    336,
#    339,
#    341,
#    344,
#    351,
#    354,
#    624,
#    625,
#    626,
#    630,
#    632,
#    637,
#    638,
#    641,
#    923,
#    924,
#    926,
#    929,
#    931,
#    934,
#    943,
#    1264,
#    1265,
#    1267,
#    1269,
#    1271,
#    1275,
#    1276,
#    1281,
#    1293,
#    1677,
#    1679,
#    1681,
#    1683,
#    1684,
#    1685,
#    1695,
#    1700),
#   'neurons': [45, 31],
#   'lags': array([5.]) * ms,
#   'times': array([1665., 1680., 1695., 1705., 1720., 1755., 1770., 3120., 3125.,
#          3130., 3150., 3160., 3185., 3190., 3205., 4615., 4620., 4630.,
#          4645., 4655., 4670., 4715., 6320., 6325., 6335., 6345., 6355.,
#          6375., 6380., 6405., 6465., 8385., 8395., 8405., 8415., 8420.,
#          8425., 8475., 8500.]) * ms,
#   'signature': (2, 39, 1),
#   'pvalue': 0.0}]

# %%
def patterns_to_df(df, patterndic, key):
    
    patterncount= (len(patterndic[key][0]))+1
    for i in patterndic[key][0]:
        keystring=keylist_spiketrains[i]
        i, j = keystring[0], int(keystring[1:])
        df.loc[j,i]=patterncount
        df=df.fillna(0)
        patterncount-=1
        
    
    return df

# %% [markdown]
# # PATTERNS SPATIAL

# %%
def get_channel_SPADE_participation(patterndic, keylist_spiketrains):
    
    '''
    Input: patterndic = Dic with keys=patternnumber, values=array of list, array[0]
            contains the participating channels of that pattern, array[1] contains the lags in between
            
    Output: a dictionary with key: channel names, e.g. A1, value: int given the number of appearances
            in any pattern 
    '''
    
    participation_dic={}
    for key in patterndic:
        for i in patterndic[key][0]:
            pd_key=keylist_spiketrains[i]
            if pd_key in participation_dic:
                participation_dic[pd_key]+=1
            else:
                participation_dic[pd_key]=1
    
    return participation_dic

# %%
pd_dic=get_channel_SPADE_participation(patterndic, keylist_spiketrains)

# %%
pd_dic
# Out:
# {'G8': 1034, 'E9': 438, 'B7': 1}

# %%
participdic['A2']+=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-494bb35c55f3> in <module>
# ----> 1 participdic['A2']+=1
#
# KeyError: 'A2'

# %%
participdic
# Out:
# {'A1': 2}

# %%
laglist = []

# %%
for i in patterns:
    i['']

# %%
keylist_spiketrains[0]
# Out:
# 'N8'

# %%
keylist_spiketrains[10]
# Out:
# 'D3'

# %%
keylist_spiketrains.index('D7')
# Out:
# 47

# %%
layer2_3list = ['A11', 'A12', 'A13', 'A14', 'A15', 'B12', 'B13', 'B14', 'B15', 'B16', 'C12', 'C13', 'C14', 'C15', 'C16', 'D13', 'D14', 'D15', 'D16', 'E13', 'E14', 'E15', 'E16', 'F13', 'F14', 'F15', 'F16', 'G13', 'G14', 'G15', 'G16', 'H13', 'H14', 'H15', 'H16', 'I13', 'I14', 'I15', 'I16', 'K13', 'K14', 'K15', 'K16', 'L13', 'L14', 'L15', 'L16', 'M13', 'M14', 'M15', 'M16', 'N13', 'N14', 'N15', 'N16', 'O13', 'O14', 'O15', 'O16', 'P12', 'P13', 'P14', 'P15', 'P16', 'R12', 'R13', 'R14', 'R15']

# %%
layer4_list = ['A10', 'B10', 'B11', 'C11', 'D11', 'D12', 'E11', 'E12', 'F11', 'F12', 'G11', 'G12', 'H11', 'H12', 'I11', 'I12', 'K11', 'K12', 'L11', 'L12', 'M11', 'M12', 'N11', 'O10', 'O11', 'P10', 'P11', 'R10', 'R11']

# %%
layer5_6list = ['A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'B4', 'B5', 'B6', 'B7', 'B8', 'B9', 'C4', 'C5', 'C6', 'C7', 'C8', 'C9', 'C10', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9', 'D10', 'E4', 'E5', 'E6', 'E7', 'E8', 'E9', 'E10', 'F4', 'F5', 'F6', 'F7', 'F8', 'F9', 'F10', 'G4', 'G5', 'G6', 'G7', 'G8', 'G9', 'G10', 'H4', 'H5', 'H6', 'H7', 'H8', 'H9', 'H10', 'I4', 'I5', 'I6', 'I7', 'I8', 'I9', 'I10', 'K4', 'K5', 'K6', 'K7', 'K8', 'K9', 'K10', 'L4', 'L5', 'L6', 'L7', 'L8', 'L9', 'L10', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'N5', 'N6', 'N7', 'N8', 'N9', 'N10', 'O5', 'O6', 'O7', 'O8', 'O9', 'P5', 'P6', 'P7', 'P8', 'P9', 'R5', 'R6', 'R7', 'R8', 'R9']

# %%
white_matter_list = ['A2', 'A3', 'B1', 'B2', 'B3', 'C1', 'C2', 'C3', 'D1', 'D2', 'D3', 'E1', 'E2', 'E3', 'F1', 'F2', 'F3', 'G1', 'G2', 'G3', 'H1', 'H2', 'H3', 'I1', 'I2', 'I3', 'K1', 'K2', 'K3', 'L1', 'L2', 'L3', 'M1', 'M2', 'M3', 'M4', 'N1', 'N2', 'N3', 'N4', 'O1', 'O2', 'O3', 'O4', 'P1', 'P2', 'P3', 'P4', 'R2', 'R3', 'R4']

# %%
layer4_list.append('O12')

# %%
columnlist =['A','B','C','D','E','F','G','H','I','K','L','M','N','O','P','R']

# %%
listdic ={}

# %%
for i in white_matter_list:
    listdic[i]=9

# %%
def getlayer_firingrate(fireratedic, layerlist):
    
    sum_all = 0
    n=0
    std=0
    mean=0
    frlist = []
    for i in layerlist:
        sum_all +=fireratedic[i]
        frlist.append(fireratedic[i])
        n+=1
    mean = sum_all/n
    mean_nump=np.mean(frlist)
    std=np.std(frlist)
    
    return mean, mean_nump, std

# %%
mean, mean_nump, std = getlayer_firingrate(fireratedic, white_matter_list)

# %%
mean
# Out:
# 1.0565978155038407

# %%
mean_nump
# Out:
# 1.0565978155038405

# %%
std
# Out:
# 2.1159404219949005
